# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
from citipy import citipy
import numpy as np
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
# Generate latitudes(-90 to 90) and longitudes(-180 to 180) using random number generator
cities=pd.DataFrame({"long":(np.random.uniform(-180,180,5000)), "lat":(np.random.uniform(-90,90,5000))})
len(cities)
# Out:
# 5000

# %%
cities_name=[]

for i in range(0,len(cities['lat'])):
    lat=cities.iloc[i]['lat']
    long=cities.iloc[i]["long"]
    city=citipy.nearest_city(lat,long)
    name=city.city_name
    cities_name.append(name)

# removing duplicate cities returned by nearest_city function
unique_cities = [x for n, x in enumerate(cities_name) if x not in cities_name[:n]]
len(unique_cities)
#len(list(dict.fromkeys(cities_name)))
# Out:
# 1394

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty lists
City = []
Lat = []
Lng = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_speed = []
Country = []
Date = []

url = "http://api.openweathermap.org/data/2.5/weather?"    #q={city name}&appid={API key}
# Build partial query url
query_url = f'{url}appid={weather_api_key}&q='

set_i = 1
a=0
b=50
for set in range(13):

    for city in unique_cities[a:b]:
        response = requests.get(f'{query_url} + {city}').json()
        try:
            City.append(response['name'])
            Lat.append(response['coord']['lat'])
            Lng.append(response['coord']['lon'])
            Max_Temp.append(response['main']['temp_max'])
            Humidity.append(response['main']['humidity'])
            Cloudiness.append(response['clouds']['all'])
            Wind_speed.append(response['wind']['speed'])
            Country.append(response['sys']['country'])
            Date.append(response['dt'])
            print(f'Processing Record {len(City)} of Set:{set_i} | {response["name"]}')
        except:
            print("City not found. Skipping...")
            pass
    a=a+50
    b=b+50
    set_i = set_i + 1
# Out:
# Processing Record 1 of Set:1 | Jamestown
# Processing Record 2 of Set:1 | Hithadhoo
# Processing Record 3 of Set:1 | Castro
# Processing Record 4 of Set:1 | Padang
# Processing Record 5 of Set:1 | Pemangkat
# Processing Record 6 of Set:1 | Butaritari
# Processing Record 7 of Set:1 | Saint Anthony
# Processing Record 8 of Set:1 | Bredasdorp
# City not found. Skipping...
# Processing Record 9 of Set:1 | Whitehorse
# Processing Record 10 of Set:1 | Albany
# Processing Record 11 of Set:1 | Souillac
# Processing Record 12 of Set:1 | Mar del Plata
# Processing Record 13 of Set:1 | Zelenoborsk
# City not found. Skipping...
# Processing Record 14 of Set:1 | Hilo
# Processing Record 15 of Set:1 | Salalah
# Processing Record 16 of Set:1 | Santa Rosa
# Processing Record 17 of Set:1 | Rikitea
# Processing Record 18 of Set:1 | Porbandar
# Processing Record 19 of Set:1 | Tuktoyaktuk
# Processing Record 20 of Set:1 | Leningradskiy
# Processing Record 21 of Set:1 | Ushuaia
# Processing Record 22 of Set:1 | Allada
# Processing Record 23 of Set:1 | Te Anau
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set:1 | Kapaa
# City not found. Skipping...
# Processing Record 25 of Set:1 | Ramnagar
# Processing Record 26 of Set:1 | Bubaque
# Processing Record 27 of Set:1 | Port Alfred
# City not found. Skipping...
# Processing Record 28 of Set:1 | Tilichiki
# City not found. Skipping...
# Processing Record 29 of Set:1 | Cherskiy
# Processing Record 30 of Set:1 | Georgetown
# Processing Record 31 of Set:1 | Upernavik
# Processing Record 32 of Set:1 | Saint-Francois
# Processing Record 33 of Set:1 | Fare
# Processing Record 34 of Set:1 | Camacha
# Processing Record 35 of Set:1 | Limulunga
# Processing Record 36 of Set:1 | Gazli
# Processing Record 37 of Set:1 | Alice Springs
# Processing Record 38 of Set:1 | Los Llanos de Aridane
# Processing Record 39 of Set:1 | Sapele
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 of Set:1 | Pacific Grove
# Processing Record 41 of Set:1 | Saint-Philippe
# Processing Record 42 of Set:2 | Pryazha
# City not found. Skipping...
# Processing Record 43 of Set:2 | Doha
# City not found. Skipping...
# Processing Record 44 of Set:2 | Marsa Matruh
# Processing Record 45 of Set:2 | Tuatapere
# Processing Record 46 of Set:2 | Busselton
# Processing Record 47 of Set:2 | Tiksi
# Processing Record 48 of Set:2 | Cape Town
# Processing Record 49 of Set:2 | Atuona
# Processing Record 50 of Set:2 | Barrow
# Processing Record 51 of Set:2 | Sungaipenuh
# Processing Record 52 of Set:2 | Lompoc
# Processing Record 53 of Set:2 | Dingle
# Processing Record 54 of Set:2 | Yulara
# Processing Record 55 of Set:2 | Lokosovo
# Processing Record 56 of Set:2 | Tasiilaq
# City not found. Skipping...
# Processing Record 57 of Set:2 | Luderitz
# Processing Record 58 of Set:2 | Atasu
# Processing Record 59 of Set:2 | Yashkul
# Processing Record 60 of Set:2 | Norman Wells
# Processing Record 61 of Set:2 | Kirakira
# Processing Record 62 of Set:2 | Lebu
# Processing Record 63 of Set:2 | Port Lincoln
# Processing Record 64 of Set:2 | Gustrow
# Processing Record 65 of Set:2 | Merrill
# Processing Record 66 of Set:2 | Korcula
# Processing Record 67 of Set:2 | Sorong
# Processing Record 68 of Set:2 | Saskylakh
# Processing Record 69 of Set:2 | Vadso
# Processing Record 70 of Set:2 | Narsaq
# Processing Record 71 of Set:2 | Coquimbo
# Processing Record 72 of Set:2 | Goderich
# Processing Record 73 of Set:2 | East London
# Processing Record 74 of Set:2 | Cabedelo
# Processing Record 75 of Set:2 | Puerto Ayora
# Processing Record 76 of Set:2 | Baykalovo
# Processing Record 77 of Set:2 | Iqaluit
# Processing Record 78 of Set:2 | Kungurtug
# Processing Record 79 of Set:2 | General Roca
# Processing Record 80 of Set:2 | Sao Filipe
# Processing Record 81 of Set:2 | Yangshan
# Processing Record 82 of Set:2 | Geraldton
# Processing Record 83 of Set:2 | Mehriz
# Processing Record 84 of Set:2 | Aklavik
# Processing Record 85 of Set:2 | Dunmore Town
# Processing Record 86 of Set:2 | Esperance
# Processing Record 87 of Set:2 | Malanje
# Processing Record 88 of Set:2 | Vila Franca do Campo
# Processing Record 89 of Set:3 | Platanos
# City not found. Skipping...
# Processing Record 90 of Set:3 | Trairi
# Processing Record 91 of Set:3 | Vaini
# City not found. Skipping...
# Processing Record 92 of Set:3 | Arraial do Cabo
# Processing Record 93 of Set:3 | Karratha
# Processing Record 94 of Set:3 | La Ronge
# Processing Record 95 of Set:3 | Punta Arenas
# Processing Record 96 of Set:3 | Inhambane
# Processing Record 97 of Set:3 | Adrar
# Processing Record 98 of Set:3 | Carnarvon
# Processing Record 99 of Set:3 | Kargopol
# City not found. Skipping...
# Processing Record 100 of Set:3 | Cachoeira do Sul
# Processing Record 101 of Set:3 | New Norfolk
# Processing Record 102 of Set:3 | Armeria
# Processing Record 103 of Set:3 | Port Elizabeth
# Processing Record 104 of Set:3 | Quatre Cocos
# Processing Record 105 of Set:3 | Yellowknife
# Processing Record 106 of Set:3 | Saint-Pierre
# Processing Record 107 of Set:3 | Jaypur
# Processing Record 108 of Set:3 | Saquarema
# Processing Record 109 of Set:3 | Thompson
# Processing Record 110 of Set:3 | Gandajika
# Processing Record 111 of Set:3 | Batagay
# Processing Record 112 of Set:3 | Coffs Harbour
# Processing Record 113 of Set:3 | El Alto
# Processing Record 114 of Set:3 | Pavlysh
# Processing Record 115 of Set:3 | Nola
# Processing Record 116 of Set:3 | Hofn
# Processing Record 117 of Set:3 | Salinas
# Processing Record 118 of Set:3 | Katsuura
# Processing Record 119 of Set:3 | Hami
# Processing Record 120 of Set:3 | Provideniya
# Processing Record 121 of Set:3 | Cao Bang
# Processing Record 122 of Set:3 | San Quintin
# Processing Record 123 of Set:3 | Bonfim
# Processing Record 124 of Set:3 | Mahebourg
# Processing Record 125 of Set:3 | Lewiston
# Processing Record 126 of Set:3 | Hobart
# City not found. Skipping...
# Processing Record 127 of Set:3 | Tual
# Processing Record 128 of Set:3 | Mount Gambier
# Processing Record 129 of Set:3 | Longyearbyen
# Processing Record 130 of Set:3 | Hermanus
# Processing Record 131 of Set:3 | North Bend
# Processing Record 132 of Set:3 | Charters Towers
# City not found. Skipping...
# Processing Record 133 of Set:3 | Kulhudhuffushi
# City not found. Skipping...
# Processing Record 134 of Set:4 | Galle
# Processing Record 135 of Set:4 | Qaanaaq
# Processing Record 136 of Set:4 | Sur
# Processing Record 137 of Set:4 | Isangel
# Processing Record 138 of Set:4 | Porto Novo
# City not found. Skipping...
# Processing Record 139 of Set:4 | Dikson
# Processing Record 140 of Set:4 | Crailsheim
# City not found. Skipping...
# Processing Record 141 of Set:4 | Victoria
# Processing Record 142 of Set:4 | Ilulissat
# Processing Record 143 of Set:4 | Fallon
# Processing Record 144 of Set:4 | Praia
# Processing Record 145 of Set:4 | Turayf
# Processing Record 146 of Set:4 | Uspenskaya
# Processing Record 147 of Set:4 | Banda Aceh
# Processing Record 148 of Set:4 | Rangapara
# Processing Record 149 of Set:4 | Klaksvik
# Processing Record 150 of Set:4 | Chuy
# Processing Record 151 of Set:4 | Necochea
# Processing Record 152 of Set:4 | Bodrum
# Processing Record 153 of Set:4 | Arman
# Processing Record 154 of Set:4 | Avarua
# Processing Record 155 of Set:4 | Nanortalik
# Processing Record 156 of Set:4 | Batemans Bay
# Processing Record 157 of Set:4 | Bluff
# Processing Record 158 of Set:4 | Bathsheba
# City not found. Skipping...
# Processing Record 159 of Set:4 | Abashiri
# Processing Record 160 of Set:4 | Wuwei
# Processing Record 161 of Set:4 | Kristinehamn
# Processing Record 162 of Set:4 | Tomatlan
# Processing Record 163 of Set:4 | Grand Gaube
# City not found. Skipping...
# Processing Record 164 of Set:4 | Ust-Karsk
# City not found. Skipping...
# Processing Record 165 of Set:4 | Tiarei
# Processing Record 166 of Set:4 | Raymond
# City not found. Skipping...
# Processing Record 167 of Set:4 | Alta Floresta
# Processing Record 168 of Set:4 | Zaraza
# Processing Record 169 of Set:4 | Basco
# Processing Record 170 of Set:4 | Guerrero Negro
# Processing Record 171 of Set:4 | Ponta do Sol
# Processing Record 172 of Set:4 | Kruisfontein
# Processing Record 173 of Set:4 | Rantepao
# Processing Record 174 of Set:4 | Solnechnyy
# Processing Record 175 of Set:4 | Nishihara
# Processing Record 176 of Set:4 | Deputatskiy
# Processing Record 177 of Set:5 | Oyem
# Processing Record 178 of Set:5 | Kulu
# Processing Record 179 of Set:5 | Khatanga
# Processing Record 180 of Set:5 | Mujiayingzi
# Processing Record 181 of Set:5 | Mitsamiouli
# Processing Record 182 of Set:5 | Vung Tau
# Processing Record 183 of Set:5 | Chokurdakh
# Processing Record 184 of Set:5 | Nelson Bay
# Processing Record 185 of Set:5 | Sitka
# Processing Record 186 of Set:5 | Dobrinka
# Processing Record 187 of Set:5 | Rwamagana
# Processing Record 188 of Set:5 | Kavaratti
# Processing Record 189 of Set:5 | Amqui
# Processing Record 190 of Set:5 | Bykovo
# Processing Record 191 of Set:5 | Saquena
# Processing Record 192 of Set:5 | Beringovskiy
# City not found. Skipping...
# Processing Record 193 of Set:5 | Cap Malheureux
# Processing Record 194 of Set:5 | Mareeba
# Processing Record 195 of Set:5 | Jerusalem
# Processing Record 196 of Set:5 | Jega
# City not found. Skipping...
# Processing Record 197 of Set:5 | Haines Junction
# Processing Record 198 of Set:5 | Codrington
# Processing Record 199 of Set:5 | Mweka
# Processing Record 200 of Set:5 | Dalvik
# Processing Record 201 of Set:5 | Lakeway
# Processing Record 202 of Set:5 | Montegranaro
# Processing Record 203 of Set:5 | Ornskoldsvik
# Processing Record 204 of Set:5 | Tocopilla
# Processing Record 205 of Set:5 | Fujieda
# Processing Record 206 of Set:5 | Portland
# Processing Record 207 of Set:5 | Ilebo
# Processing Record 208 of Set:5 | Labuhan
# Processing Record 209 of Set:5 | Pyinmana
# Processing Record 210 of Set:5 | Kahului
# Processing Record 211 of Set:5 | Pavlovskiy
# Processing Record 212 of Set:5 | Ribeira Grande
# Processing Record 213 of Set:5 | Bay Roberts
# Processing Record 214 of Set:5 | Jasper
# Processing Record 215 of Set:5 | Torbay
# Processing Record 216 of Set:5 | Upata
# Processing Record 217 of Set:5 | Riyadh
# Processing Record 218 of Set:5 | Kroya
# Processing Record 219 of Set:5 | Bengkulu
# City not found. Skipping...
# Processing Record 220 of Set:5 | Bethel
# Processing Record 221 of Set:5 | Hasaki
# Processing Record 222 of Set:5 | Thinadhoo
# Processing Record 223 of Set:5 | Point Pedro
# Processing Record 224 of Set:6 | College
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 225 of Set:6 | Lima
# Processing Record 226 of Set:6 | Pevek
# Processing Record 227 of Set:6 | Cayenne
# Processing Record 228 of Set:6 | Chapais
# Processing Record 229 of Set:6 | Petropavlovsk-Kamchatskiy
# City not found. Skipping...
# Processing Record 230 of Set:6 | Harper
# Processing Record 231 of Set:6 | Rorvik
# Processing Record 232 of Set:6 | Mirabad
# Processing Record 233 of Set:6 | Vila Velha
# Processing Record 234 of Set:6 | Champerico
# Processing Record 235 of Set:6 | Namatanai
# Processing Record 236 of Set:6 | Saint-Paul
# City not found. Skipping...
# Processing Record 237 of Set:6 | Sarakhs
# Processing Record 238 of Set:6 | Faanui
# Processing Record 239 of Set:6 | Yagodnoye
# Processing Record 240 of Set:6 | Predivinsk
# Processing Record 241 of Set:6 | Iquique
# Processing Record 242 of Set:6 | Cidreira
# City not found. Skipping...
# Processing Record 243 of Set:6 | Berlevag
# Processing Record 244 of Set:6 | Hambantota
# Processing Record 245 of Set:6 | Tautira
# Processing Record 246 of Set:6 | Gazojak
# Processing Record 247 of Set:6 | Vao
# Processing Record 248 of Set:6 | San Martin
# Processing Record 249 of Set:6 | Araouane
# Processing Record 250 of Set:6 | Ferrol
# City not found. Skipping...
# Processing Record 251 of Set:6 | Poum
# City not found. Skipping...
# Processing Record 252 of Set:6 | Kashi
# Processing Record 253 of Set:6 | Sangar
# Processing Record 254 of Set:6 | Sorland
# Processing Record 255 of Set:6 | Lafiagi
# Processing Record 256 of Set:6 | Okha
# Processing Record 257 of Set:6 | Batagay-Alyta
# Processing Record 258 of Set:6 | Miles City
# City not found. Skipping...
# Processing Record 259 of Set:6 | Kincardine
# Processing Record 260 of Set:6 | Cabo San Lucas
# Processing Record 261 of Set:6 | Teopisca
# Processing Record 262 of Set:6 | Salinopolis
# Processing Record 263 of Set:6 | Foumban
# Processing Record 264 of Set:6 | Morant Bay
# Processing Record 265 of Set:7 | Severo-Kurilsk
# Processing Record 266 of Set:7 | Kadhan
# Processing Record 267 of Set:7 | Zhigansk
# Processing Record 268 of Set:7 | Gisborne
# Processing Record 269 of Set:7 | Lagoa
# Processing Record 270 of Set:7 | Minnedosa
# Processing Record 271 of Set:7 | Sinnamary
# Processing Record 272 of Set:7 | Rauma
# Processing Record 273 of Set:7 | Kutum
# Processing Record 274 of Set:7 | Glenwood Springs
# Processing Record 275 of Set:7 | Pottsville
# Processing Record 276 of Set:7 | Ikom
# Processing Record 277 of Set:7 | Lang Son
# Processing Record 278 of Set:7 | Wajima
# City not found. Skipping...
# Processing Record 279 of Set:7 | Morshansk
# Processing Record 280 of Set:7 | Zhifang
# City not found. Skipping...
# Processing Record 281 of Set:7 | Kavieng
# Processing Record 282 of Set:7 | Lahaina
# Processing Record 283 of Set:7 | Saldanha
# City not found. Skipping...
# Processing Record 284 of Set:7 | Namibe
# Processing Record 285 of Set:7 | Caravelas
# Processing Record 286 of Set:7 | Serra Branca
# Processing Record 287 of Set:7 | Uruburetama
# Processing Record 288 of Set:7 | Egvekinot
# Processing Record 289 of Set:7 | Asau
# Processing Record 290 of Set:7 | Yerbogachen
# Processing Record 291 of Set:7 | Sepuka
# Processing Record 292 of Set:7 | Kodiak
# Processing Record 293 of Set:7 | Gulfport
# Processing Record 294 of Set:7 | Richland
# Processing Record 295 of Set:7 | Umm Kaddadah
# City not found. Skipping...
# Processing Record 296 of Set:7 | Ancud
# Processing Record 297 of Set:7 | Grindavik
# Processing Record 298 of Set:7 | Brookhaven
# Processing Record 299 of Set:7 | Bilibino
# Processing Record 300 of Set:7 | Rio Grande da Serra
# Processing Record 301 of Set:7 | Rocha
# City not found. Skipping...
# Processing Record 302 of Set:7 | Baloda Bazar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 303 of Set:7 | Botro
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 304 of Set:7 | Kiama
# Processing Record 305 of Set:7 | Monrovia
# Processing Record 306 of Set:8 | Lata
# Processing Record 307 of Set:8 | Ouesso
# Processing Record 308 of Set:8 | Lavrentiya
# Processing Record 309 of Set:8 | Palmer
# Processing Record 310 of Set:8 | Sola
# Processing Record 311 of Set:8 | Kiruna
# City not found. Skipping...
# Processing Record 312 of Set:8 | Hamilton
# Processing Record 313 of Set:8 | Saldana
# Processing Record 314 of Set:8 | Tangkak
# Processing Record 315 of Set:8 | Muros
# Processing Record 316 of Set:8 | Bambous Virieux
# Processing Record 317 of Set:8 | Latung
# Processing Record 318 of Set:8 | Usuki
# Processing Record 319 of Set:8 | Margate
# City not found. Skipping...
# Processing Record 320 of Set:8 | Vagamo
# Processing Record 321 of Set:8 | Waingapu
# Processing Record 322 of Set:8 | Zhangye
# Processing Record 323 of Set:8 | Ndele
# Processing Record 324 of Set:8 | Kangaatsiaq
# Processing Record 325 of Set:8 | Belmonte
# Processing Record 326 of Set:8 | Sabang
# Processing Record 327 of Set:8 | Fernie
# Processing Record 328 of Set:8 | Alpatovo
# Processing Record 329 of Set:8 | South Lake Tahoe
# Processing Record 330 of Set:8 | Lordelo
# Processing Record 331 of Set:8 | Awbari
# Processing Record 332 of Set:8 | Takoradi
# Processing Record 333 of Set:8 | Chifeng
# Processing Record 334 of Set:8 | Holalkere
# Processing Record 335 of Set:8 | Srikakulam
# Processing Record 336 of Set:8 | Kandrian
# Processing Record 337 of Set:8 | Camana
# Processing Record 338 of Set:8 | Yar-Sale
# City not found. Skipping...
# Processing Record 339 of Set:8 | Sembakung
# Processing Record 340 of Set:8 | Den Helder
# Processing Record 341 of Set:8 | Hay River
# Processing Record 342 of Set:8 | Innisfail
# Processing Record 343 of Set:8 | Ketchikan
# Processing Record 344 of Set:8 | Bressuire
# Processing Record 345 of Set:8 | Rawson
# Processing Record 346 of Set:8 | Hauknes
# City not found. Skipping...
# Processing Record 347 of Set:8 | Suratgarh
# Processing Record 348 of Set:8 | Sao Joao da Barra
# Processing Record 349 of Set:8 | Prieska
# Processing Record 350 of Set:8 | Arcachon
# Processing Record 351 of Set:8 | Nanakuli
# Processing Record 352 of Set:9 | Tadine
# Processing Record 353 of Set:9 | Ahipara
# Processing Record 354 of Set:9 | Talnakh
# Processing Record 355 of Set:9 | Lakes Entrance
# Processing Record 356 of Set:9 | Pangnirtung
# Processing Record 357 of Set:9 | Viedma
# Processing Record 358 of Set:9 | Boguchany
# Processing Record 359 of Set:9 | Oktyabrskoye
# Processing Record 360 of Set:9 | Stephenville
# Processing Record 361 of Set:9 | Hualmay
# City not found. Skipping...
# Processing Record 362 of Set:9 | Bay City
# Processing Record 363 of Set:9 | Kjollefjord
# Processing Record 364 of Set:9 | Benjamin Constant
# Processing Record 365 of Set:9 | San Patricio
# Processing Record 366 of Set:9 | Treinta y Tres
# Processing Record 367 of Set:9 | Nyurba
# Processing Record 368 of Set:9 | San Juan
# Processing Record 369 of Set:9 | Lanivtsi
# Processing Record 370 of Set:9 | Tiznit
# Processing Record 371 of Set:9 | Calvinia
# Processing Record 372 of Set:9 | Tuy Hoa
# Processing Record 373 of Set:9 | Shiyan
# Processing Record 374 of Set:9 | Cam Ranh
# Processing Record 375 of Set:9 | Clyde River
# Processing Record 376 of Set:9 | Kutulik
# Processing Record 377 of Set:9 | Neiafu
# Processing Record 378 of Set:9 | Port Hardy
# City not found. Skipping...
# Processing Record 379 of Set:9 | Asyut
# Processing Record 380 of Set:9 | Roswell
# Processing Record 381 of Set:9 | Alofi
# City not found. Skipping...
# Processing Record 382 of Set:9 | Pangkalanbuun
# Processing Record 383 of Set:9 | Cordoba
# Processing Record 384 of Set:9 | Buraydah
# Processing Record 385 of Set:9 | Gilbues
# Processing Record 386 of Set:9 | Tessalit
# Processing Record 387 of Set:9 | Longonjo
# Processing Record 388 of Set:9 | Almaznyy
# Processing Record 389 of Set:9 | Chicama
# Processing Record 390 of Set:9 | Ambon
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 391 of Set:9 | Rio de Jesus
# City not found. Skipping...
# Processing Record 392 of Set:9 | Nabire
# Processing Record 393 of Set:9 | Haverfordwest
# Processing Record 394 of Set:9 | Konevo
# City not found. Skipping...
# Processing Record 395 of Set:10 | Paamiut
# Processing Record 396 of Set:10 | Turukhansk
# Processing Record 397 of Set:10 | Sembe
# Processing Record 398 of Set:10 | Pisco
# Processing Record 399 of Set:10 | Alyangula
# Processing Record 400 of Set:10 | Jacareacanga
# Processing Record 401 of Set:10 | Milagres
# Processing Record 402 of Set:10 | Roseburg
# Processing Record 403 of Set:10 | Larsnes
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 404 of Set:10 | Ibra
# Processing Record 405 of Set:10 | Baykit
# Processing Record 406 of Set:10 | Srednekolymsk
# City not found. Skipping...
# Processing Record 407 of Set:10 | Saltillo
# Processing Record 408 of Set:10 | Dezhou
# Processing Record 409 of Set:10 | Barcelos
# Processing Record 410 of Set:10 | Kodinsk
# City not found. Skipping...
# Processing Record 411 of Set:10 | Rimouski
# City not found. Skipping...
# Processing Record 412 of Set:10 | Manaure
# Processing Record 413 of Set:10 | Tabursuq
# City not found. Skipping...
# Processing Record 414 of Set:10 | Tezu
# Processing Record 415 of Set:10 | Vanavara
# Processing Record 416 of Set:10 | Laurel
# Processing Record 417 of Set:10 | Bara
# Processing Record 418 of Set:10 | Fortuna
# Processing Record 419 of Set:10 | Dunedin
# Processing Record 420 of Set:10 | Mangrol
# Processing Record 421 of Set:10 | Acari
# Processing Record 422 of Set:10 | Ignacio Zaragoza
# City not found. Skipping...
# Processing Record 423 of Set:10 | Kingaroy
# Processing Record 424 of Set:10 | San Rafael
# Processing Record 425 of Set:10 | Saint George
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 426 of Set:10 | Taoudenni
# Processing Record 427 of Set:10 | Pingliang
# Processing Record 428 of Set:10 | Namtsy
# Processing Record 429 of Set:10 | Melilla
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 430 of Set:10 | Ilo
# Processing Record 431 of Set:10 | Luangwa
# Processing Record 432 of Set:10 | Sisimiut
# Processing Record 433 of Set:11 | Ajdabiya
# City not found. Skipping...
# Processing Record 434 of Set:11 | Eyl
# Processing Record 435 of Set:11 | Maksi
# Processing Record 436 of Set:11 | Fairbanks
# Processing Record 437 of Set:11 | Stettler
# Processing Record 438 of Set:11 | Mehamn
# Processing Record 439 of Set:11 | Tabas
# City not found. Skipping...
# Processing Record 440 of Set:11 | Christchurch
# Processing Record 441 of Set:11 | Walvis Bay
# Processing Record 442 of Set:11 | Port-Cartier
# City not found. Skipping...
# Processing Record 443 of Set:11 | Saint-Augustin
# Processing Record 444 of Set:11 | Senanga
# City not found. Skipping...
# Processing Record 445 of Set:11 | Marinette
# Processing Record 446 of Set:11 | Langham
# Processing Record 447 of Set:11 | Port Blair
# Processing Record 448 of Set:11 | Billings
# Processing Record 449 of Set:11 | Svetlyy
# Processing Record 450 of Set:11 | Sibut
# Processing Record 451 of Set:11 | Vanimo
# City not found. Skipping...
# Processing Record 452 of Set:11 | Amazar
# Processing Record 453 of Set:11 | Ponta Delgada
# Processing Record 454 of Set:11 | Mitu
# Processing Record 455 of Set:11 | Shush
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 456 of Set:11 | Manuk Mangkaw
# Processing Record 457 of Set:11 | Lodja
# Processing Record 458 of Set:11 | Westport
# Processing Record 459 of Set:11 | Fonte Boa
# Processing Record 460 of Set:11 | Altagracia de Orituco
# Processing Record 461 of Set:11 | Prince Albert
# Processing Record 462 of Set:11 | Opuwo
# Processing Record 463 of Set:11 | Beatrice
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 464 of Set:11 | Denpasar
# Processing Record 465 of Set:11 | San Ignacio
# Processing Record 466 of Set:11 | Imbituba
# Processing Record 467 of Set:11 | Zhengjiatun
# Processing Record 468 of Set:11 | Fort Nelson
# City not found. Skipping...
# Processing Record 469 of Set:11 | Muisne
# Processing Record 470 of Set:11 | Cotacachi
# Processing Record 471 of Set:11 | Miramar
# Processing Record 472 of Set:12 | Grand-Lahou
# Processing Record 473 of Set:12 | Puerto Leguizamo
# Processing Record 474 of Set:12 | Nambucca Heads
# Processing Record 475 of Set:12 | Polson
# Processing Record 476 of Set:12 | Panama City
# Processing Record 477 of Set:12 | Noormarkku
# Processing Record 478 of Set:12 | Aksarka
# City not found. Skipping...
# Processing Record 479 of Set:12 | Comodoro Rivadavia
# Processing Record 480 of Set:12 | Khorramshahr
# Processing Record 481 of Set:12 | Belle Fourche
# Processing Record 482 of Set:12 | Caucaia
# Processing Record 483 of Set:12 | Waipawa
# Processing Record 484 of Set:12 | Zhuhai
# Processing Record 485 of Set:12 | Acajutla
# Processing Record 486 of Set:12 | Prince Rupert
# Processing Record 487 of Set:12 | Mangan
# Processing Record 488 of Set:12 | Ubatuba
# Processing Record 489 of Set:12 | Tarauaca
# Processing Record 490 of Set:12 | Burns Lake
# Processing Record 491 of Set:12 | Mahibadhoo
# City not found. Skipping...
# Processing Record 492 of Set:12 | Itacare
# Processing Record 493 of Set:12 | Chase
# Processing Record 494 of Set:12 | Filotion
# Processing Record 495 of Set:12 | Brae
# Processing Record 496 of Set:12 | Touros
# Processing Record 497 of Set:12 | Bensonville
# City not found. Skipping...
# Processing Record 498 of Set:12 | Trinidad
# Processing Record 499 of Set:12 | Karasjok
# Processing Record 500 of Set:12 | Hovd
# Processing Record 501 of Set:12 | Tsalenjikha
# Processing Record 502 of Set:12 | Burnie
# Processing Record 503 of Set:12 | Plettenberg Bay
# Processing Record 504 of Set:12 | Hobyo
# Processing Record 505 of Set:12 | Atherton
# Processing Record 506 of Set:12 | Tabuk
# Processing Record 507 of Set:12 | Ostrovnoy
# Processing Record 508 of Set:12 | Sadovoye
# Processing Record 509 of Set:12 | Konstantinovka
# City not found. Skipping...
# Processing Record 510 of Set:12 | Aykhal
# Processing Record 511 of Set:12 | Klaten
# Processing Record 512 of Set:12 | Itaperucu
# City not found. Skipping...
# Processing Record 513 of Set:12 | Ndende
# Processing Record 514 of Set:12 | Valentin Gomez Farias
# City not found. Skipping...
# Processing Record 515 of Set:12 | Kawalu
# Processing Record 516 of Set:13 | Santa Isabel do Rio Negro
# Processing Record 517 of Set:13 | Butterworth
# Processing Record 518 of Set:13 | Malanville
# Processing Record 519 of Set:13 | Dehloran
# City not found. Skipping...
# Processing Record 520 of Set:13 | The Valley
# Processing Record 521 of Set:13 | Karlshus
# Processing Record 522 of Set:13 | Chimoio
# Processing Record 523 of Set:13 | Port Augusta
# Processing Record 524 of Set:13 | Surt
# Processing Record 525 of Set:13 | Manokwari
# Processing Record 526 of Set:13 | Yarada
# Processing Record 527 of Set:13 | Disraeli
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 528 of Set:13 | Peterhead
# Processing Record 529 of Set:13 | Agropoli
# Processing Record 530 of Set:13 | Loviisa
# City not found. Skipping...
# Processing Record 531 of Set:13 | Bayevo
# Processing Record 532 of Set:13 | Wainwright
# Processing Record 533 of Set:13 | Verkhnetulomskiy
# Processing Record 534 of Set:13 | Massakory
# Processing Record 535 of Set:13 | Nome
# Processing Record 536 of Set:13 | Dandong
# City not found. Skipping...
# Processing Record 537 of Set:13 | Braganca
# Processing Record 538 of Set:13 | Panchagarh
# Processing Record 539 of Set:13 | Tarko-Sale
# City not found. Skipping...
# Processing Record 540 of Set:13 | Moron
# Processing Record 541 of Set:13 | Neepawa
# Processing Record 542 of Set:13 | Twin Falls
# Processing Record 543 of Set:13 | Toora-Khem
# Processing Record 544 of Set:13 | Upington
# Processing Record 545 of Set:13 | Dungarpur
# City not found. Skipping...
# Processing Record 546 of Set:13 | La Palma
# Processing Record 547 of Set:13 | Paka
# Processing Record 548 of Set:13 | Korla
# Processing Record 549 of Set:13 | Providencia
# Processing Record 550 of Set:13 | Werda
# Processing Record 551 of Set:13 | Dubrovnik
# City not found. Skipping...
# Processing Record 552 of Set:13 | Vestmannaeyjar
# City not found. Skipping...
# Processing Record 553 of Set:13 | Kholodnyy
# Processing Record 554 of Set:13 | Bodden Town
# Processing Record 555 of Set:13 | Ust-Tsilma
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({
    "City" : City,
    "Lat" : Lat,
    "Lng" : Lng,
    "Max Temp" : Max_Temp,
    "Humidity" : Humidity,
    "Cloudiness" : Cloudiness,
    "Wind Speed" : Wind_speed,
    "Country" : Country,
    "Date" : Date
})
weather_df.head()
weather_df.to_csv("weather.csv")

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  555.000000  555.000000  555.000000  555.000000  555.000000  555.000000
# mean    20.573707   11.474227  289.625658   68.753153   57.704505    3.644829
# std     33.569075   91.534213   12.399200   22.646920   39.897286    2.863993
# min    -54.800000 -179.166700  247.000000    4.000000    0.000000    0.000000
# 25%     -6.219450  -68.491300  281.620000   58.000000   11.000000    1.560000
# 50%     24.687700   15.640100  291.000000   73.000000   74.000000    2.870000
# 75%     48.799500   92.700000  299.350000   86.000000   98.000000    4.900000
# max     78.218600  179.316700  314.820000  100.000000  100.000000   20.060000
#
#                Date
# count  5.550000e+02
# mean   1.634479e+09
# std    2.958424e+02
# min    1.634478e+09
# 25%    1.634479e+09
# 50%    1.634479e+09
# 75%    1.634479e+09
# max    1.634480e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
print(f'{sum(weather_df["Humidity"] > 100)} cities have a humidity > 100%')
df = weather_df.head(100)
# Out:
# 0 cities have a humidity > 100%

# %%
#  Get the indices of cities that have humidity over 100%.
hum_out = weather_df[weather_df["Humidity"] > 100].index

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df.drop(hum_out, inplace=False)
clean_city_data.describe()

sum(clean_city_data.duplicated())
# Out:
# 0

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#need to find how to insert date for all the plots
plt.scatter(clean_city_data["Lat"],clean_city_data["Max Temp"], edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Maximum Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

plt.show()

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Humidity"], edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Cloudiness"], edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Wind Speed"], edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
