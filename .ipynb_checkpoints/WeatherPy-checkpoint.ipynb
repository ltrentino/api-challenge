# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
from citipy import citipy
import numpy as np
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import weather_api_key

# %% [markdown]
# ## Generate Cities List

# %%
# Generate latitudes(-90 to 90) and longitudes(-180 to 180) using random number generator
cities=pd.DataFrame({"long":(np.random.uniform(-180,180,5000)), "lat":(np.random.uniform(-90,90,5000))})
len(cities)
# Out:
# 5000

# %%
cities_name=[]

for i in range(0,len(cities['lat'])):
    lat=cities.iloc[i]['lat']
    long=cities.iloc[i]["long"]
    city=citipy.nearest_city(lat,long)
    name=city.city_name
    cities_name.append(name)

# removing duplicate cities returned by nearest_city function
unique_cities = [x for n, x in enumerate(cities_name) if x not in cities_name[:n]]
len(unique_cities)
#len(list(dict.fromkeys(cities_name)))
# Out:
# 1391

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty lists
City = []
Lat = []
Lng = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_speed = []
Country = []
Date = []

url = "http://api.openweathermap.org/data/2.5/weather?"    #q={city name}&appid={API key}
# Build partial query url
query_url = f'{url}appid={weather_api_key}&q='

set_i = 1
a=0
b=50
for set in range(13):

    for city in unique_cities[a:b]:
        response = requests.get(f'{query_url} + {city}').json()
        try:
            City.append(response['name'])
            Lat.append(response['coord']['lat'])
            Lng.append(response['coord']['lon'])
            Max_Temp.append(response['main']['temp_max'])
            Humidity.append(response['main']['humidity'])
            Cloudiness.append(response['clouds']['all'])
            Wind_speed.append(response['wind']['speed'])
            Country.append(response['sys']['country'])
            Date.append(response['dt'])
            print(f'Processing Record {len(City)} of Set:{set_i} | {response["name"]}')
        except:
            print("City not found. Skipping...")
            pass
    a=a+50
    b=b+50
    set_i = set_i + 1
# Out:
# Processing Record 1 of Set:1 | Indiaroba
# Processing Record 2 of Set:1 | Hobart
# Processing Record 3 of Set:1 | Bredasdorp
# Processing Record 4 of Set:1 | Georgetown
# Processing Record 5 of Set:1 | Atambua
# City not found. Skipping...
# Processing Record 6 of Set:1 | Punta Arenas
# Processing Record 7 of Set:1 | Siyabuswa
# Processing Record 8 of Set:1 | Walvis Bay
# Processing Record 9 of Set:1 | Hirado
# Processing Record 10 of Set:1 | Ushuaia
# Processing Record 11 of Set:1 | Comodoro Rivadavia
# City not found. Skipping...
# Processing Record 12 of Set:1 | Carnarvon
# Processing Record 13 of Set:1 | Albany
# Processing Record 14 of Set:1 | Marabba
# Processing Record 15 of Set:1 | West Bay
# Processing Record 16 of Set:1 | Kapaa
# City not found. Skipping...
# Processing Record 17 of Set:1 | Butaritari
# Processing Record 18 of Set:1 | Egvekinot
# Processing Record 19 of Set:1 | Pevek
# Processing Record 20 of Set:1 | Atasu
# Processing Record 21 of Set:1 | Olinda
# Processing Record 22 of Set:1 | New Norfolk
# Processing Record 23 of Set:1 | Rikitea
# Processing Record 24 of Set:1 | Guerrero Negro
# Processing Record 25 of Set:1 | Torbay
# Processing Record 26 of Set:1 | Hermanus
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of Set:1 | Atuona
# Processing Record 28 of Set:1 | Savannah Bight
# Processing Record 29 of Set:1 | Tarbes
# Processing Record 30 of Set:1 | Busselton
# Processing Record 31 of Set:1 | Luderitz
# Processing Record 32 of Set:1 | Arraial do Cabo
# Processing Record 33 of Set:1 | Qaanaaq
# Processing Record 34 of Set:1 | Touros
# Processing Record 35 of Set:1 | Te Anau
# Processing Record 36 of Set:1 | Skagen
# Processing Record 37 of Set:1 | Jamestown
# Processing Record 38 of Set:1 | Labuhan
# Processing Record 39 of Set:1 | Saldanha
# Processing Record 40 of Set:1 | Barrow
# Processing Record 41 of Set:1 | Bay Roberts
# Processing Record 42 of Set:1 | Mogadishu
# Processing Record 43 of Set:1 | Mar del Plata
# Processing Record 44 of Set:1 | Hasaki
# Processing Record 45 of Set:2 | Lianzhou
# City not found. Skipping...
# Processing Record 46 of Set:2 | Potoci
# Processing Record 47 of Set:2 | Bluff
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set:2 | Abha
# Processing Record 49 of Set:2 | Upernavik
# Processing Record 50 of Set:2 | Vaini
# Processing Record 51 of Set:2 | Teguise
# Processing Record 52 of Set:2 | Anloga
# Processing Record 53 of Set:2 | Turiacu
# Processing Record 54 of Set:2 | Obo
# Processing Record 55 of Set:2 | Tuktoyaktuk
# Processing Record 56 of Set:2 | Cascais
# Processing Record 57 of Set:2 | Dicabisagan
# Processing Record 58 of Set:2 | Mantua
# Processing Record 59 of Set:2 | Jutai
# Processing Record 60 of Set:2 | Castro
# Processing Record 61 of Set:2 | Khorixas
# Processing Record 62 of Set:2 | Tezu
# Processing Record 63 of Set:2 | Majene
# City not found. Skipping...
# Processing Record 64 of Set:2 | Severo-Kurilsk
# Processing Record 65 of Set:2 | Berbera
# Processing Record 66 of Set:2 | Ribeira Grande
# City not found. Skipping...
# Processing Record 67 of Set:2 | Saskylakh
# Processing Record 68 of Set:2 | Vilhena
# Processing Record 69 of Set:2 | Hilo
# Processing Record 70 of Set:2 | Thompson
# Processing Record 71 of Set:2 | Cabo San Lucas
# Processing Record 72 of Set:2 | Hambantota
# City not found. Skipping...
# Processing Record 73 of Set:2 | Yellowknife
# Processing Record 74 of Set:2 | Maksatikha
# City not found. Skipping...
# Processing Record 75 of Set:2 | Anadyr
# City not found. Skipping...
# Processing Record 76 of Set:2 | Poronaysk
# Processing Record 77 of Set:2 | Shimanovsk
# Processing Record 78 of Set:2 | Komsomolskiy
# Processing Record 79 of Set:2 | Dali
# Processing Record 80 of Set:2 | Aripuana
# City not found. Skipping...
# Processing Record 81 of Set:2 | Talnakh
# Processing Record 82 of Set:2 | Kolobrzeg
# Processing Record 83 of Set:2 | Flinders
# Processing Record 84 of Set:2 | Ponta do Sol
# Processing Record 85 of Set:2 | Iwaki
# Processing Record 86 of Set:3 | Poso
# Processing Record 87 of Set:3 | Sembakung
# Processing Record 88 of Set:3 | Exu
# Processing Record 89 of Set:3 | Vardo
# City not found. Skipping...
# Processing Record 90 of Set:3 | Beloha
# Processing Record 91 of Set:3 | Hovd
# Processing Record 92 of Set:3 | Iseyin
# City not found. Skipping...
# Processing Record 93 of Set:3 | Ancud
# Processing Record 94 of Set:3 | Tambacounda
# Processing Record 95 of Set:3 | Mehamn
# Processing Record 96 of Set:3 | Cape Town
# Processing Record 97 of Set:3 | Tiksi
# City not found. Skipping...
# Processing Record 98 of Set:3 | East London
# Processing Record 99 of Set:3 | Chenzhou
# Processing Record 100 of Set:3 | Hithadhoo
# Processing Record 101 of Set:3 | Leningradskiy
# Processing Record 102 of Set:3 | Natal
# Processing Record 103 of Set:3 | Rio Gallegos
# Processing Record 104 of Set:3 | Sitka
# Processing Record 105 of Set:3 | Zhangjiakou
# Processing Record 106 of Set:3 | Lavrentiya
# Processing Record 107 of Set:3 | Longyearbyen
# City not found. Skipping...
# Processing Record 108 of Set:3 | Lebu
# Processing Record 109 of Set:3 | Senno
# Processing Record 110 of Set:3 | Cruzeiro do Sul
# Processing Record 111 of Set:3 | Kinshasa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 112 of Set:3 | Port Alfred
# City not found. Skipping...
# Processing Record 113 of Set:3 | Iqaluit
# City not found. Skipping...
# Processing Record 114 of Set:3 | Catuday
# Processing Record 115 of Set:3 | Bloemfontein
# Processing Record 116 of Set:3 | Pontianak
# Processing Record 117 of Set:3 | Phatthalung
# Processing Record 118 of Set:3 | Leh
# Processing Record 119 of Set:3 | Chuy
# Processing Record 120 of Set:3 | San Rafael
# Processing Record 121 of Set:3 | Vao
# Processing Record 122 of Set:3 | Panguna
# Processing Record 123 of Set:3 | Yulara
# Processing Record 124 of Set:3 | Cherskiy
# Processing Record 125 of Set:3 | Tabou
# City not found. Skipping...
# Processing Record 126 of Set:3 | Sola
# Processing Record 127 of Set:4 | Abbeville
# Processing Record 128 of Set:4 | Shugurovo
# Processing Record 129 of Set:4 | Okhotsk
# Processing Record 130 of Set:4 | Laguna
# City not found. Skipping...
# Processing Record 131 of Set:4 | Bykovo
# Processing Record 132 of Set:4 | Dakar
# Processing Record 133 of Set:4 | Dikson
# Processing Record 134 of Set:4 | Doctor Mora
# Processing Record 135 of Set:4 | Katsina
# Processing Record 136 of Set:4 | Maragogi
# Processing Record 137 of Set:4 | Tilichiki
# Processing Record 138 of Set:4 | Pisco
# Processing Record 139 of Set:4 | Palmer
# City not found. Skipping...
# Processing Record 140 of Set:4 | Nadadores
# Processing Record 141 of Set:4 | Ottawa
# Processing Record 142 of Set:4 | Honavar
# Processing Record 143 of Set:4 | Urucui
# Processing Record 144 of Set:4 | Port Hedland
# Processing Record 145 of Set:4 | Half Moon Bay
# Processing Record 146 of Set:4 | Kindu
# Processing Record 147 of Set:4 | Porlamar
# Processing Record 148 of Set:4 | Katsuura
# Processing Record 149 of Set:4 | Hailar
# Processing Record 150 of Set:4 | Avarua
# City not found. Skipping...
# Processing Record 151 of Set:4 | Lima
# City not found. Skipping...
# Processing Record 152 of Set:4 | Loreto
# Processing Record 153 of Set:4 | Bogandinskiy
# Processing Record 154 of Set:4 | Puerto Ayora
# Processing Record 155 of Set:4 | Okahandja
# Processing Record 156 of Set:4 | Tsiroanomandidy
# Processing Record 157 of Set:4 | Iquique
# Processing Record 158 of Set:4 | Bambous Virieux
# City not found. Skipping...
# Processing Record 159 of Set:4 | Maniitsoq
# Processing Record 160 of Set:4 | Bengkulu
# Processing Record 161 of Set:4 | Auki
# Processing Record 162 of Set:4 | Hami
# Processing Record 163 of Set:4 | Marsh Harbour
# Processing Record 164 of Set:4 | Camabatela
# Processing Record 165 of Set:4 | Saint-Philippe
# Processing Record 166 of Set:4 | Sao Filipe
# Processing Record 167 of Set:4 | Tottori
# City not found. Skipping...
# Processing Record 168 of Set:4 | Alofi
# City not found. Skipping...
# Processing Record 169 of Set:4 | Saint-Francois
# Processing Record 170 of Set:5 | Souillac
# Processing Record 171 of Set:5 | Codrington
# Processing Record 172 of Set:5 | Sur
# Processing Record 173 of Set:5 | Aklavik
# Processing Record 174 of Set:5 | Maturin
# Processing Record 175 of Set:5 | Gilgit
# Processing Record 176 of Set:5 | Mumford
# Processing Record 177 of Set:5 | Humberto de Campos
# City not found. Skipping...
# Processing Record 178 of Set:5 | Nouakchott
# Processing Record 179 of Set:5 | Tasiilaq
# Processing Record 180 of Set:5 | Cayenne
# Processing Record 181 of Set:5 | Mendoza
# Processing Record 182 of Set:5 | Paragould
# Processing Record 183 of Set:5 | Makokou
# Processing Record 184 of Set:5 | Khatanga
# Processing Record 185 of Set:5 | Sinnamary
# Processing Record 186 of Set:5 | Hualmay
# Processing Record 187 of Set:5 | Fortuna
# Processing Record 188 of Set:5 | Padang
# Processing Record 189 of Set:5 | Sao Joao da Barra
# Processing Record 190 of Set:5 | San Quintin
# Processing Record 191 of Set:5 | Kitama
# Processing Record 192 of Set:5 | Vestmannaeyjar
# Processing Record 193 of Set:5 | Silifke
# City not found. Skipping...
# Processing Record 194 of Set:5 | Havre-Saint-Pierre
# Processing Record 195 of Set:5 | Kruisfontein
# Processing Record 196 of Set:5 | Pekan
# Processing Record 197 of Set:5 | Tiarei
# City not found. Skipping...
# Processing Record 198 of Set:5 | Stornoway
# City not found. Skipping...
# Processing Record 199 of Set:5 | Loa Janan
# Processing Record 200 of Set:5 | Medvedka
# Processing Record 201 of Set:5 | Havre
# Processing Record 202 of Set:5 | Norman Wells
# Processing Record 203 of Set:5 | Santa Fe
# Processing Record 204 of Set:5 | Carballo
# Processing Record 205 of Set:5 | Eyl
# Processing Record 206 of Set:5 | Cabedelo
# City not found. Skipping...
# Processing Record 207 of Set:5 | Dharangaon
# Processing Record 208 of Set:5 | Tazovskiy
# Processing Record 209 of Set:5 | Salalah
# Processing Record 210 of Set:5 | Saint-Pierre
# Processing Record 211 of Set:5 | Port Elizabeth
# City not found. Skipping...
# Processing Record 212 of Set:5 | Kodiak
# Processing Record 213 of Set:5 | Bullhead City
# Processing Record 214 of Set:6 | Lompoc
# Processing Record 215 of Set:6 | Brigantine
# City not found. Skipping...
# Processing Record 216 of Set:6 | Novichikha
# Processing Record 217 of Set:6 | Maumere
# Processing Record 218 of Set:6 | Berlevag
# City not found. Skipping...
# Processing Record 219 of Set:6 | Navahrudak
# Processing Record 220 of Set:6 | Onguday
# Processing Record 221 of Set:6 | Ostrovnoy
# Processing Record 222 of Set:6 | Narsaq
# Processing Record 223 of Set:6 | Jeremie
# Processing Record 224 of Set:6 | Puerto Baquerizo Moreno
# Processing Record 225 of Set:6 | Ahipara
# City not found. Skipping...
# Processing Record 226 of Set:6 | Khandyga
# City not found. Skipping...
# Processing Record 227 of Set:6 | Arnissa
# Processing Record 228 of Set:6 | Sovetskiy
# Processing Record 229 of Set:6 | Kungurtug
# Processing Record 230 of Set:6 | Lagoa
# Processing Record 231 of Set:6 | Port-Cartier
# City not found. Skipping...
# Processing Record 232 of Set:6 | Provideniya
# Processing Record 233 of Set:6 | Braintree
# Processing Record 234 of Set:6 | Tual
# Processing Record 235 of Set:6 | Richards Bay
# Processing Record 236 of Set:6 | Lata
# Processing Record 237 of Set:6 | Sisimiut
# Processing Record 238 of Set:6 | Ilulissat
# Processing Record 239 of Set:6 | Tingi
# Processing Record 240 of Set:6 | Bayburt
# City not found. Skipping...
# Processing Record 241 of Set:6 | San Juan
# Processing Record 242 of Set:6 | Gualaquiza
# Processing Record 243 of Set:6 | Bethel
# Processing Record 244 of Set:6 | Sabha
# Processing Record 245 of Set:6 | Ulaangom
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 246 of Set:6 | Geraldton
# Processing Record 247 of Set:6 | Puerto Gaitan
# Processing Record 248 of Set:6 | Nyurba
# Processing Record 249 of Set:6 | Owando
# Processing Record 250 of Set:6 | Qurbus
# Processing Record 251 of Set:6 | Nanortalik
# Processing Record 252 of Set:6 | Douentza
# Processing Record 253 of Set:6 | Yicheng
# Processing Record 254 of Set:6 | Shingu
# Processing Record 255 of Set:6 | Namibe
# City not found. Skipping...
# Processing Record 256 of Set:7 | Puerto Ayacucho
# Processing Record 257 of Set:7 | Buala
# Processing Record 258 of Set:7 | Dingle
# Processing Record 259 of Set:7 | Port-Gentil
# Processing Record 260 of Set:7 | Deputatskiy
# Processing Record 261 of Set:7 | Cidreira
# City not found. Skipping...
# Processing Record 262 of Set:7 | Dunedin
# Processing Record 263 of Set:7 | Carutapera
# Processing Record 264 of Set:7 | Mokhsogollokh
# Processing Record 265 of Set:7 | Poum
# Processing Record 266 of Set:7 | Muros
# City not found. Skipping...
# Processing Record 267 of Set:7 | Pio IX
# Processing Record 268 of Set:7 | Roebourne
# Processing Record 269 of Set:7 | Saint-Augustin
# Processing Record 270 of Set:7 | Grand-Santi
# Processing Record 271 of Set:7 | Marsa Matruh
# Processing Record 272 of Set:7 | Revda
# Processing Record 273 of Set:7 | Jati
# Processing Record 274 of Set:7 | Srednekolymsk
# Processing Record 275 of Set:7 | Kirsanov
# Processing Record 276 of Set:7 | Roald
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 277 of Set:7 | North Bend
# Processing Record 278 of Set:7 | Vila Velha
# Processing Record 279 of Set:7 | Lyaskelya
# Processing Record 280 of Set:7 | Darasun
# Processing Record 281 of Set:7 | Yarmouth
# Processing Record 282 of Set:7 | Baker City
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 283 of Set:7 | Saint George
# Processing Record 284 of Set:7 | Sokolka
# Processing Record 285 of Set:7 | Omboue
# Processing Record 286 of Set:7 | Awbari
# Processing Record 287 of Set:7 | Sucre
# Processing Record 288 of Set:7 | Skowhegan
# City not found. Skipping...
# Processing Record 289 of Set:7 | Togur
# Processing Record 290 of Set:7 | Margate
# Processing Record 291 of Set:7 | Leshukonskoye
# Processing Record 292 of Set:7 | Victoria
# Processing Record 293 of Set:7 | Thaba Nchu
# Processing Record 294 of Set:7 | Tuatapere
# Processing Record 295 of Set:7 | Gogrial
# Processing Record 296 of Set:7 | Kirakira
# Processing Record 297 of Set:7 | Teberda
# Processing Record 298 of Set:8 | Nampula
# Processing Record 299 of Set:8 | Dwarka
# Processing Record 300 of Set:8 | Minab
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 301 of Set:8 | High Level
# Processing Record 302 of Set:8 | Klyuchi
# City not found. Skipping...
# Processing Record 303 of Set:8 | Bandarbeyla
# Processing Record 304 of Set:8 | Abay
# Processing Record 305 of Set:8 | Najran
# Processing Record 306 of Set:8 | Novorzhev
# Processing Record 307 of Set:8 | Mahajanga
# Processing Record 308 of Set:8 | Kavieng
# Processing Record 309 of Set:8 | Rio Grande
# City not found. Skipping...
# Processing Record 310 of Set:8 | Chokurdakh
# Processing Record 311 of Set:8 | Meylan
# Processing Record 312 of Set:8 | Nanakuli
# Processing Record 313 of Set:8 | La Ronge
# Processing Record 314 of Set:8 | Farafangana
# Processing Record 315 of Set:8 | Bangkal
# Processing Record 316 of Set:8 | Luganville
# Processing Record 317 of Set:8 | Mitsamiouli
# Processing Record 318 of Set:8 | Baghdad
# Processing Record 319 of Set:8 | Adrar
# City not found. Skipping...
# Processing Record 320 of Set:8 | Qandala
# Processing Record 321 of Set:8 | Camacha
# Processing Record 322 of Set:8 | Evensk
# Processing Record 323 of Set:8 | Pedernales
# Processing Record 324 of Set:8 | Skibbereen
# City not found. Skipping...
# Processing Record 325 of Set:8 | Qianan
# City not found. Skipping...
# Processing Record 326 of Set:8 | Inhambane
# Processing Record 327 of Set:8 | Chernyshevskiy
# Processing Record 328 of Set:8 | Roma
# Processing Record 329 of Set:8 | Hongjiang
# Processing Record 330 of Set:8 | Bat Yam
# Processing Record 331 of Set:8 | Celestun
# Processing Record 332 of Set:8 | Acari
# Processing Record 333 of Set:8 | Timizart
# Processing Record 334 of Set:8 | Fairbanks
# Processing Record 335 of Set:8 | Eirunepe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 336 of Set:8 | Iquitos
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 337 of Set:9 | Daraitan
# Processing Record 338 of Set:9 | Lorengau
# Processing Record 339 of Set:9 | Shimoda
# Processing Record 340 of Set:9 | Jakar
# Processing Record 341 of Set:9 | Ati
# Processing Record 342 of Set:9 | Zaoyang
# Processing Record 343 of Set:9 | Moron
# Processing Record 344 of Set:9 | Xam Nua
# Processing Record 345 of Set:9 | Baherden
# Processing Record 346 of Set:9 | Cartagena
# Processing Record 347 of Set:9 | Kadyy
# Processing Record 348 of Set:9 | Kahului
# Processing Record 349 of Set:9 | Muncar
# Processing Record 350 of Set:9 | Belaya Gora
# Processing Record 351 of Set:9 | Jiayuguan
# Processing Record 352 of Set:9 | Balsas
# Processing Record 353 of Set:9 | Kavaratti
# Processing Record 354 of Set:9 | Oussouye
# Processing Record 355 of Set:9 | Esperance
# City not found. Skipping...
# Processing Record 356 of Set:9 | Along
# Processing Record 357 of Set:9 | Santa Maria
# Processing Record 358 of Set:9 | Necochea
# City not found. Skipping...
# Processing Record 359 of Set:9 | Matanzas
# Processing Record 360 of Set:9 | Shakiso
# Processing Record 361 of Set:9 | Bolobo
# Processing Record 362 of Set:9 | Clyde River
# Processing Record 363 of Set:9 | Solnechnyy
# Processing Record 364 of Set:9 | Faanui
# Processing Record 365 of Set:9 | Dolores
# Processing Record 366 of Set:9 | Hofn
# Processing Record 367 of Set:9 | Uvarovo
# Processing Record 368 of Set:9 | Port Keats
# Processing Record 369 of Set:9 | Mahibadhoo
# Processing Record 370 of Set:9 | Beaupre
# Processing Record 371 of Set:9 | Thunder Bay
# Processing Record 372 of Set:9 | Kaseda
# Processing Record 373 of Set:9 | Saint Anthony
# Processing Record 374 of Set:9 | Christchurch
# Processing Record 375 of Set:9 | Zelenogorskiy
# Processing Record 376 of Set:9 | Yarada
# Processing Record 377 of Set:9 | Xingtai
# Processing Record 378 of Set:9 | West Plains
# Processing Record 379 of Set:9 | Naze
# Processing Record 380 of Set:9 | Saint-Joseph
# Processing Record 381 of Set:9 | Reconquista
# Processing Record 382 of Set:9 | Itoman
# Processing Record 383 of Set:9 | Dapaong
# City not found. Skipping...
# Processing Record 384 of Set:10 | Staroaleyskoye
# Processing Record 385 of Set:10 | Campeche
# Processing Record 386 of Set:10 | Goderich
# Processing Record 387 of Set:10 | Santa Marinella
# City not found. Skipping...
# Processing Record 388 of Set:10 | Black River
# Processing Record 389 of Set:10 | Vila Franca do Campo
# City not found. Skipping...
# Processing Record 390 of Set:10 | Demmin
# Processing Record 391 of Set:10 | Ust-Koksa
# Processing Record 392 of Set:10 | Zyryanka
# Processing Record 393 of Set:10 | Bonthe
# Processing Record 394 of Set:10 | Paita
# Processing Record 395 of Set:10 | Chegutu
# Processing Record 396 of Set:10 | Mirabad
# City not found. Skipping...
# Processing Record 397 of Set:10 | Phan Thiet
# Processing Record 398 of Set:10 | Novyy Urengoy
# Processing Record 399 of Set:10 | Mpika
# Processing Record 400 of Set:10 | Zhumadian
# Processing Record 401 of Set:10 | Ruzsa
# Processing Record 402 of Set:10 | San Patricio
# Processing Record 403 of Set:10 | Nalut
# Processing Record 404 of Set:10 | Altoona
# Processing Record 405 of Set:10 | Danielskuil
# Processing Record 406 of Set:10 | Opoczno
# Processing Record 407 of Set:10 | Palu
# Processing Record 408 of Set:10 | Nouadhibou
# Processing Record 409 of Set:10 | Nome
# Processing Record 410 of Set:10 | Port Blair
# Processing Record 411 of Set:10 | Tefe
# Processing Record 412 of Set:10 | Praia da Vitoria
# City not found. Skipping...
# Processing Record 413 of Set:10 | Parrita
# City not found. Skipping...
# Processing Record 414 of Set:10 | Klaksvik
# Processing Record 415 of Set:10 | Aliganj
# Processing Record 416 of Set:10 | Bilibino
# Processing Record 417 of Set:10 | Cassilandia
# Processing Record 418 of Set:10 | Mende
# Processing Record 419 of Set:10 | Morondava
# Processing Record 420 of Set:10 | Bubaque
# Processing Record 421 of Set:10 | Pangody
# Processing Record 422 of Set:10 | Kununurra
# Processing Record 423 of Set:10 | Mutoko
# Processing Record 424 of Set:10 | Kaeo
# Processing Record 425 of Set:10 | Nantucket
# Processing Record 426 of Set:10 | San Carlos de Bariloche
# Processing Record 427 of Set:10 | Zhaotong
# Processing Record 428 of Set:10 | Imbituba
# City not found. Skipping...
# Processing Record 429 of Set:11 | Barra do Garcas
# Processing Record 430 of Set:11 | Beringovskiy
# Processing Record 431 of Set:11 | Ponta Delgada
# Processing Record 432 of Set:11 | Severodvinsk
# Processing Record 433 of Set:11 | Chanute
# Processing Record 434 of Set:11 | Belawan
# Processing Record 435 of Set:11 | Staryy Nadym
# Processing Record 436 of Set:11 | Llangefni
# Processing Record 437 of Set:11 | Saint-Georges
# City not found. Skipping...
# Processing Record 438 of Set:11 | Batagay
# Processing Record 439 of Set:11 | Havelock
# Processing Record 440 of Set:11 | Nong Bua
# Processing Record 441 of Set:11 | Uvira
# City not found. Skipping...
# Processing Record 442 of Set:11 | Chistogorskiy
# Processing Record 443 of Set:11 | Hokitika
# Processing Record 444 of Set:11 | Riberalta
# Processing Record 445 of Set:11 | Irati
# Processing Record 446 of Set:11 | Kieta
# Processing Record 447 of Set:11 | Surt
# City not found. Skipping...
# Processing Record 448 of Set:11 | Illela
# Processing Record 449 of Set:11 | Misratah
# Processing Record 450 of Set:11 | Ishigaki
# Processing Record 451 of Set:11 | Gigmoto
# Processing Record 452 of Set:11 | Richmond
# City not found. Skipping...
# Processing Record 453 of Set:11 | Kotelnich
# Processing Record 454 of Set:11 | Killybegs
# Processing Record 455 of Set:11 | Sainte-Maxime
# Processing Record 456 of Set:11 | Seshcha
# Processing Record 457 of Set:11 | Antofagasta
# City not found. Skipping...
# Processing Record 458 of Set:11 | Boda
# Processing Record 459 of Set:11 | Port Shepstone
# Processing Record 460 of Set:11 | Zhangye
# City not found. Skipping...
# Processing Record 461 of Set:11 | Zhigansk
# Processing Record 462 of Set:11 | Shu
# Processing Record 463 of Set:11 | Raymondville
# Processing Record 464 of Set:11 | Bathsheba
# Processing Record 465 of Set:11 | Bud
# Processing Record 466 of Set:11 | Riverton
# Processing Record 467 of Set:11 | West Wendover
# Processing Record 468 of Set:11 | Ligayan
# Processing Record 469 of Set:11 | Husavik
# Processing Record 470 of Set:11 | Charlestown
# City not found. Skipping...
# Processing Record 471 of Set:12 | Jawhar
# Processing Record 472 of Set:12 | Kupang
# Processing Record 473 of Set:12 | Boshkengash
# Processing Record 474 of Set:12 | Escanaba
# Processing Record 475 of Set:12 | Beira
# Processing Record 476 of Set:12 | Hit
# Processing Record 477 of Set:12 | San Vicente
# Processing Record 478 of Set:12 | Abu Dhabi
# Processing Record 479 of Set:12 | Juneau
# City not found. Skipping...
# Processing Record 480 of Set:12 | Pitimbu
# Processing Record 481 of Set:12 | Pierre
# Processing Record 482 of Set:12 | Alpena
# Processing Record 483 of Set:12 | Vila
# Processing Record 484 of Set:12 | Manicore
# City not found. Skipping...
# Processing Record 485 of Set:12 | Kawalu
# Processing Record 486 of Set:12 | Susangerd
# Processing Record 487 of Set:12 | Kizema
# Processing Record 488 of Set:12 | Bambanglipuro
# Processing Record 489 of Set:12 | Chitrakonda
# Processing Record 490 of Set:12 | Nongpoh
# Processing Record 491 of Set:12 | Beyneu
# Processing Record 492 of Set:12 | Yerbogachen
# Processing Record 493 of Set:12 | Muscat
# Processing Record 494 of Set:12 | Tibati
# Processing Record 495 of Set:12 | Polson
# Processing Record 496 of Set:12 | Rantauprapat
# Processing Record 497 of Set:12 | Adamas
# Processing Record 498 of Set:12 | Darhan
# Processing Record 499 of Set:12 | Xacmaz
# Processing Record 500 of Set:12 | Suamico
# Processing Record 501 of Set:12 | Zheleznodorozhnyy
# Processing Record 502 of Set:12 | Palora
# Processing Record 503 of Set:12 | Nemuro
# Processing Record 504 of Set:12 | Jiangyou
# Processing Record 505 of Set:12 | Deer Lake
# Processing Record 506 of Set:12 | Lieksa
# Processing Record 507 of Set:12 | Huarmey
# Processing Record 508 of Set:12 | Swan River
# Processing Record 509 of Set:12 | Nicoya
# City not found. Skipping...
# Processing Record 510 of Set:12 | Lagoa Santa
# City not found. Skipping...
# Processing Record 511 of Set:12 | Port Lavaca
# Processing Record 512 of Set:12 | Pasighat
# Processing Record 513 of Set:12 | Kovdor
# Processing Record 514 of Set:12 | Lavumisa
# Processing Record 515 of Set:12 | Mount Isa
# Processing Record 516 of Set:12 | Verkhnevilyuysk
# Processing Record 517 of Set:13 | Oyon
# Processing Record 518 of Set:13 | Paamiut
# City not found. Skipping...
# Processing Record 519 of Set:13 | Praya
# Processing Record 520 of Set:13 | Koyelga
# Processing Record 521 of Set:13 | Miri
# Processing Record 522 of Set:13 | Marystown
# City not found. Skipping...
# Processing Record 523 of Set:13 | Kloulklubed
# Processing Record 524 of Set:13 | Cap Malheureux
# Processing Record 525 of Set:13 | Marfino
# Processing Record 526 of Set:13 | Mahebourg
# Processing Record 527 of Set:13 | Chauk
# Processing Record 528 of Set:13 | Oranjestad
# Processing Record 529 of Set:13 | Hay River
# Processing Record 530 of Set:13 | Krutikha
# Processing Record 531 of Set:13 | Ahuimanu
# Processing Record 532 of Set:13 | Ruthin
# Processing Record 533 of Set:13 | Parana
# Processing Record 534 of Set:13 | Haimen
# Processing Record 535 of Set:13 | Faxinal
# Processing Record 536 of Set:13 | Isangel
# Processing Record 537 of Set:13 | Vilyuysk
# Processing Record 538 of Set:13 | Sioux Lookout
# Processing Record 539 of Set:13 | Kudahuvadhoo
# Processing Record 540 of Set:13 | Jumla
# Processing Record 541 of Set:13 | Sembabule
# Processing Record 542 of Set:13 | Damaturu
# City not found. Skipping...
# Processing Record 543 of Set:13 | Coquimbo
# Processing Record 544 of Set:13 | Polis
# Processing Record 545 of Set:13 | Eagle Pass
# Processing Record 546 of Set:13 | Portland
# Processing Record 547 of Set:13 | Sterling
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 548 of Set:13 | Eydhafushi
# Processing Record 549 of Set:13 | Gouyave
# Processing Record 550 of Set:13 | Abnub
# Processing Record 551 of Set:13 | Lengshuijiang
# Processing Record 552 of Set:13 | The Valley
# Processing Record 553 of Set:13 | Srivardhan
# Processing Record 554 of Set:13 | Eldorado
# Processing Record 555 of Set:13 | Iberia
# Processing Record 556 of Set:13 | Amahai
# Processing Record 557 of Set:13 | Churapcha
# Processing Record 558 of Set:13 | Nikolayevka
# Processing Record 559 of Set:13 | Udachnyy
# City not found. Skipping...
# Processing Record 560 of Set:13 | Baykit

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({
    "City" : City,
    "Lat" : Lat,
    "Lng" : Lng,
    "Max Temp" : Max_Temp,
    "Humidity" : Humidity,
    "Cloudiness" : Cloudiness,
    "Wind Speed" : Wind_speed,
    "Country" : Country,
    "Date" : Date
})
weather_df.head()
weather_df.to_csv("weather.csv")

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  560.000000  560.000000  560.000000  560.000000   560.00000  560.000000
# mean    20.072213   16.673137  288.865268   72.689286    57.73750    3.383482
# std     32.755688   88.147846   11.096508   20.031011    39.30297    2.684373
# min    -54.800000 -179.166700  250.900000    9.000000     0.00000    0.000000
# 25%     -7.267475  -60.551175  281.202500   61.750000    16.00000    1.447500
# 50%     23.117300   21.055800  289.785000   77.000000    72.00000    2.795000
# 75%     48.104225   92.925000  298.317500   87.250000    99.00000    4.630000
# max     78.218600  179.316700  312.140000  100.000000   100.00000   17.690000
#
#                Date
# count  5.600000e+02
# mean   1.634529e+09
# std    2.806304e+02
# min    1.634529e+09
# 25%    1.634529e+09
# 50%    1.634529e+09
# 75%    1.634530e+09
# max    1.634530e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
print(f'{sum(weather_df["Humidity"] > 100)} cities have a humidity > 100%')
df = weather_df.head(100)
# Out:
# 0 cities have a humidity > 100%

# %%
#  Get the indices of cities that have humidity over 100%.
hum_out = weather_df[weather_df["Humidity"] > 100].index

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df.drop(hum_out, inplace=False)
clean_city_data.describe()

sum(clean_city_data.duplicated())
# Out:
# 0

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_data.[head]()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Indiaroba -11.5192  -37.5117    295.62        91          90        1.72
# 1      Hobart -42.8794  147.3294    290.38        71          75        0.45
# 2  Bredasdorp -34.5322   20.0403    281.56        73           9        1.58
# 3  Georgetown   6.8045  -58.1553    297.31        83          67        3.18
# 4     Atambua  -9.1061  124.8925    304.31        55          36        2.87
#
#   Country        Date
# 0      BR  1634528750
# 1      AU  1634528664
# 2      ZA  1634528753
# 3      GY  1634528755
# 4      ID  1634528758

# %%
#need to find how to insert date for all the plots
plt.scatter(clean_city_data["Lat"],clean_city_data["Max Temp"], edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Maximum Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")

plt.show()

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Humidity"], edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Cloudiness"], edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Wind Speed"], edgecolor="black")
plt.grid()
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
