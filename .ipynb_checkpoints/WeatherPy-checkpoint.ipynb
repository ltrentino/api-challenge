# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
from citipy import citipy
import numpy as np
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import weather_api_key
from datetime import datetime
from scipy.stats import linregress

# %% [markdown]
# ## Generate Cities List

# %%
# Generate latitudes(-90 to 90) and longitudes(-180 to 180) using random number generator
cities=pd.DataFrame({"long":(np.random.uniform(-180,180,5000)), "lat":(np.random.uniform(-90,90,5000))})
len(cities)
# Out:
# 5000

# %%
cities_name=[]

for i in range(0,len(cities['lat'])):
    lat=cities.iloc[i]['lat']
    long=cities.iloc[i]["long"]
    city=citipy.nearest_city(lat,long)
    name=city.city_name
    cities_name.append(name)

# removing duplicate cities returned by nearest_city function
unique_cities = [x for n, x in enumerate(cities_name) if x not in cities_name[:n]]
len(unique_cities)
#len(list(dict.fromkeys(cities_name)))
# Out:
# 1394

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create empty lists
City = []
Lat = []
Lng = []
Max_Temp = []
Humidity = []
Cloudiness = []
Wind_speed = []
Country = []
Date = []

url = "http://api.openweathermap.org/data/2.5/weather?"    #q={city name}&appid={API key}
# Build partial query url
query_url = f'{url}appid={weather_api_key}&q='

set_i = 1
a=0
b=50
for set in range(13):

    for city in unique_cities[a:b]:
        response = requests.get(f'{query_url} + {city}').json()
        try:
            City.append(response['name'])
            Lat.append(response['coord']['lat'])
            Lng.append(response['coord']['lon'])
            Max_Temp.append(response['main']['temp_max'])
            Humidity.append(response['main']['humidity'])
            Cloudiness.append(response['clouds']['all'])
            Wind_speed.append(response['wind']['speed'])
            Country.append(response['sys']['country'])
            Date.append(response['dt'])
            print(f'Processing Record {len(City)} of Set:{set_i} | {response["name"]}')
        except:
            print("City not found. Skipping...")
            pass
    a=a+50
    b=b+50
    set_i = set_i + 1
# Out:
# Processing Record 1 of Set:1 | Dikson
# City not found. Skipping...
# Processing Record 2 of Set:1 | New Norfolk
# Processing Record 3 of Set:1 | Slave Lake
# City not found. Skipping...
# Processing Record 4 of Set:1 | Hasaki
# Processing Record 5 of Set:1 | Aleksandrovsk-Sakhalinskiy
# Processing Record 6 of Set:1 | Gimli
# Processing Record 7 of Set:1 | Ushuaia
# Processing Record 8 of Set:1 | Kahului
# Processing Record 9 of Set:1 | Yellowknife
# Processing Record 10 of Set:1 | Punta Arenas
# Processing Record 11 of Set:1 | Busselton
# Processing Record 12 of Set:1 | Bluff
# Processing Record 13 of Set:1 | Derbent
# Processing Record 14 of Set:1 | Cayenne
# Processing Record 15 of Set:1 | Namibe
# Processing Record 16 of Set:1 | Saint-Pierre
# Processing Record 17 of Set:1 | Kasongo-Lunda
# Processing Record 18 of Set:1 | Saskylakh
# Processing Record 19 of Set:1 | Cape Town
# Processing Record 20 of Set:1 | Bredasdorp
# Processing Record 21 of Set:1 | Vaini
# Processing Record 22 of Set:1 | Bloemfontein
# Processing Record 23 of Set:1 | Albany
# Processing Record 24 of Set:1 | Hun
# Processing Record 25 of Set:1 | Upernavik
# Processing Record 26 of Set:1 | Coahuayana
# Processing Record 27 of Set:1 | Quatre Cocos
# Processing Record 28 of Set:1 | Avarua
# Processing Record 29 of Set:1 | West Wendover
# City not found. Skipping...
# Processing Record 30 of Set:1 | Shimoda
# Processing Record 31 of Set:1 | Sao Jose da Coroa Grande
# Processing Record 32 of Set:1 | Aripuana
# Processing Record 33 of Set:1 | Sorland
# Processing Record 34 of Set:1 | Tuktoyaktuk
# Processing Record 35 of Set:1 | Jamestown
# Processing Record 36 of Set:1 | Cornwall
# City not found. Skipping...
# Processing Record 37 of Set:1 | Saint George
# Processing Record 38 of Set:1 | Aksarka
# Processing Record 39 of Set:1 | Geraldton
# Processing Record 40 of Set:1 | Luoyang
# Processing Record 41 of Set:1 | Mujiayingzi
# Processing Record 42 of Set:1 | Vasto
# Processing Record 43 of Set:1 | Bethel
# City not found. Skipping...
# Processing Record 44 of Set:1 | Atuona
# Processing Record 45 of Set:1 | Broome
# City not found. Skipping...
# Processing Record 46 of Set:2 | Taksimo
# Processing Record 47 of Set:2 | Hithadhoo
# Processing Record 48 of Set:2 | Kapaa
# Processing Record 49 of Set:2 | Ribeira Grande
# City not found. Skipping...
# Processing Record 50 of Set:2 | Leshukonskoye
# Processing Record 51 of Set:2 | Arraial do Cabo
# Processing Record 52 of Set:2 | Tasiilaq
# Processing Record 53 of Set:2 | Khatanga
# Processing Record 54 of Set:2 | Cidreira
# City not found. Skipping...
# Processing Record 55 of Set:2 | Boda
# Processing Record 56 of Set:2 | Puerto Ayora
# Processing Record 57 of Set:2 | Georgetown
# Processing Record 58 of Set:2 | East London
# Processing Record 59 of Set:2 | Urengoy
# Processing Record 60 of Set:2 | Lompoc
# Processing Record 61 of Set:2 | Muros
# Processing Record 62 of Set:2 | Port Alfred
# Processing Record 63 of Set:2 | Kalevala
# Processing Record 64 of Set:2 | Sao Joao da Barra
# City not found. Skipping...
# Processing Record 65 of Set:2 | Hobart
# City not found. Skipping...
# Processing Record 66 of Set:2 | Isangel
# Processing Record 67 of Set:2 | Elizabeth City
# Processing Record 68 of Set:2 | Cherskiy
# Processing Record 69 of Set:2 | Ermelo
# Processing Record 70 of Set:2 | Port Elizabeth
# Processing Record 71 of Set:2 | Kananga
# Processing Record 72 of Set:2 | Seybaplaya
# Processing Record 73 of Set:2 | Senador Guiomard
# City not found. Skipping...
# Processing Record 74 of Set:2 | Chincha Alta
# Processing Record 75 of Set:2 | Mecca
# Processing Record 76 of Set:2 | Lerwick
# Processing Record 77 of Set:2 | Butaritari
# City not found. Skipping...
# Processing Record 78 of Set:2 | Pisco
# Processing Record 79 of Set:2 | Caravelas
# Processing Record 80 of Set:2 | Qaanaaq
# Processing Record 81 of Set:2 | Yoichi
# Processing Record 82 of Set:2 | Samfya
# Processing Record 83 of Set:2 | Luderitz
# Processing Record 84 of Set:2 | Vostok
# City not found. Skipping...
# Processing Record 85 of Set:2 | Severo-Kurilsk
# Processing Record 86 of Set:2 | Jackson
# City not found. Skipping...
# Processing Record 87 of Set:3 | Castro
# Processing Record 88 of Set:3 | Iqaluit
# Processing Record 89 of Set:3 | Bilibino
# Processing Record 90 of Set:3 | Ossora
# Processing Record 91 of Set:3 | Kamaishi
# Processing Record 92 of Set:3 | Honiara
# Processing Record 93 of Set:3 | Tuatapere
# Processing Record 94 of Set:3 | Plettenberg Bay
# City not found. Skipping...
# Processing Record 95 of Set:3 | Rikitea
# Processing Record 96 of Set:3 | Honningsvag
# Processing Record 97 of Set:3 | Bambous Virieux
# Processing Record 98 of Set:3 | Aklavik
# Processing Record 99 of Set:3 | Kodiak
# City not found. Skipping...
# Processing Record 100 of Set:3 | Barrow
# City not found. Skipping...
# Processing Record 101 of Set:3 | Souillac
# Processing Record 102 of Set:3 | Hitachi
# Processing Record 103 of Set:3 | Victoria
# Processing Record 104 of Set:3 | Kiama
# Processing Record 105 of Set:3 | Ketchikan
# Processing Record 106 of Set:3 | Richards Bay
# Processing Record 107 of Set:3 | Yvetot
# Processing Record 108 of Set:3 | Butte
# Processing Record 109 of Set:3 | Sale
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 110 of Set:3 | Nguruka
# Processing Record 111 of Set:3 | Sampit
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 112 of Set:3 | Saldanha
# Processing Record 113 of Set:3 | Thayetmyo
# Processing Record 114 of Set:3 | Kidal
# Processing Record 115 of Set:3 | Comodoro Rivadavia
# Processing Record 116 of Set:3 | Xining
# Processing Record 117 of Set:3 | Katsuura
# City not found. Skipping...
# Processing Record 118 of Set:3 | Puntarenas
# Processing Record 119 of Set:3 | Bilma
# Processing Record 120 of Set:3 | Kondinskoye
# City not found. Skipping...
# Processing Record 121 of Set:3 | Mar del Plata
# Processing Record 122 of Set:3 | Jaru
# Processing Record 123 of Set:3 | Yulara
# Processing Record 124 of Set:3 | Hilo
# Processing Record 125 of Set:3 | Ostersund
# Processing Record 126 of Set:3 | Prince Rupert
# Processing Record 127 of Set:3 | Hermanus
# Processing Record 128 of Set:4 | College
# Processing Record 129 of Set:4 | Camacha
# Processing Record 130 of Set:4 | Dingalan
# Processing Record 131 of Set:4 | Severodvinsk
# City not found. Skipping...
# Processing Record 132 of Set:4 | Marienburg
# City not found. Skipping...
# Processing Record 133 of Set:4 | Mahebourg
# City not found. Skipping...
# Processing Record 134 of Set:4 | Salalah
# Processing Record 135 of Set:4 | Arlit
# Processing Record 136 of Set:4 | Tiksi
# Processing Record 137 of Set:4 | Antigonish
# Processing Record 138 of Set:4 | Xam Nua
# City not found. Skipping...
# Processing Record 139 of Set:4 | Portland
# Processing Record 140 of Set:4 | Thinadhoo
# Processing Record 141 of Set:4 | Seoul
# Processing Record 142 of Set:4 | Coxim
# Processing Record 143 of Set:4 | Osuna
# Processing Record 144 of Set:4 | Nilokheri
# Processing Record 145 of Set:4 | Progreso
# Processing Record 146 of Set:4 | Bambanglipuro
# Processing Record 147 of Set:4 | Poum
# Processing Record 148 of Set:4 | Saint-Philippe
# Processing Record 149 of Set:4 | Pevek
# Processing Record 150 of Set:4 | Kununurra
# Processing Record 151 of Set:4 | La Ronge
# Processing Record 152 of Set:4 | Provideniya
# Processing Record 153 of Set:4 | Santa Lucia
# Processing Record 154 of Set:4 | Te Anau
# Processing Record 155 of Set:4 | Tondano
# Processing Record 156 of Set:4 | Lebu
# Processing Record 157 of Set:4 | Umm Lajj
# Processing Record 158 of Set:4 | Kavaratti
# Processing Record 159 of Set:4 | Nishihara
# Processing Record 160 of Set:4 | Boulsa
# Processing Record 161 of Set:4 | Ilheus
# Processing Record 162 of Set:4 | Sao Filipe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 163 of Set:4 | Bongandanga
# Processing Record 164 of Set:4 | Yichang
# Processing Record 165 of Set:4 | Prata
# Processing Record 166 of Set:4 | Harnosand
# Processing Record 167 of Set:4 | Novopavlovka
# Processing Record 168 of Set:4 | Aasiaat
# Processing Record 169 of Set:4 | Tigil
# Processing Record 170 of Set:4 | Tamale
# Processing Record 171 of Set:4 | Narsaq
# Processing Record 172 of Set:5 | North Bend
# Processing Record 173 of Set:5 | Osmena
# City not found. Skipping...
# Processing Record 174 of Set:5 | Lata
# Processing Record 175 of Set:5 | Sangar
# Processing Record 176 of Set:5 | Aswan
# Processing Record 177 of Set:5 | Paamiut
# Processing Record 178 of Set:5 | Salym
# Processing Record 179 of Set:5 | Barra do Garcas
# Processing Record 180 of Set:5 | Moroni
# Processing Record 181 of Set:5 | Lagoa
# Processing Record 182 of Set:5 | Yermakovskoye
# City not found. Skipping...
# Processing Record 183 of Set:5 | Kiunga
# Processing Record 184 of Set:5 | Grindavik
# Processing Record 185 of Set:5 | Ukholovo
# Processing Record 186 of Set:5 | San-Pedro
# Processing Record 187 of Set:5 | Bengkulu
# Processing Record 188 of Set:5 | Chota
# Processing Record 189 of Set:5 | Kosh-Agach
# Processing Record 190 of Set:5 | Kropotkin
# Processing Record 191 of Set:5 | Abaza
# City not found. Skipping...
# Processing Record 192 of Set:5 | Cartagena del Chaira
# Processing Record 193 of Set:5 | Al
# Processing Record 194 of Set:5 | Kontagora
# Processing Record 195 of Set:5 | Codrington
# Processing Record 196 of Set:5 | Benghazi
# Processing Record 197 of Set:5 | Maldonado
# Processing Record 198 of Set:5 | Pangnirtung
# Processing Record 199 of Set:5 | Russell
# Processing Record 200 of Set:5 | Ostrovnoy
# Processing Record 201 of Set:5 | Puerto Madryn
# Processing Record 202 of Set:5 | Tashla
# Processing Record 203 of Set:5 | Chuy
# Processing Record 204 of Set:5 | Chagoda
# Processing Record 205 of Set:5 | Nalut
# Processing Record 206 of Set:5 | Nelson Bay
# Processing Record 207 of Set:5 | Barra do Bugres
# Processing Record 208 of Set:5 | Acarau
# City not found. Skipping...
# Processing Record 209 of Set:5 | Yarim
# Processing Record 210 of Set:5 | Gigmoto
# Processing Record 211 of Set:5 | Dandong
# Processing Record 212 of Set:5 | Kampot
# Processing Record 213 of Set:5 | Chokurdakh
# Processing Record 214 of Set:5 | Chapais
# Processing Record 215 of Set:5 | Dwarka
# Processing Record 216 of Set:5 | Brae
# Processing Record 217 of Set:5 | Porterville
# Processing Record 218 of Set:6 | Marabba
# Processing Record 219 of Set:6 | Longyearbyen
# Processing Record 220 of Set:6 | Kaa-Khem
# City not found. Skipping...
# Processing Record 221 of Set:6 | Fuerte Olimpo
# Processing Record 222 of Set:6 | Yakima
# Processing Record 223 of Set:6 | Hualmay
# Processing Record 224 of Set:6 | Mariakani
# Processing Record 225 of Set:6 | Nkhotakota
# Processing Record 226 of Set:6 | Wasilla
# Processing Record 227 of Set:6 | Srednekolymsk
# Processing Record 228 of Set:6 | Lipari
# Processing Record 229 of Set:6 | Ancud
# Processing Record 230 of Set:6 | Charters Towers
# Processing Record 231 of Set:6 | Tazovskiy
# City not found. Skipping...
# Processing Record 232 of Set:6 | Araouane
# Processing Record 233 of Set:6 | Clyde River
# Processing Record 234 of Set:6 | Marsa Matruh
# Processing Record 235 of Set:6 | Nanortalik
# Processing Record 236 of Set:6 | Madison
# Processing Record 237 of Set:6 | Cabra
# City not found. Skipping...
# Processing Record 238 of Set:6 | Porbandar
# Processing Record 239 of Set:6 | Atar
# Processing Record 240 of Set:6 | Alta Floresta
# Processing Record 241 of Set:6 | Lasa
# Processing Record 242 of Set:6 | Amahai
# Processing Record 243 of Set:6 | Sorong
# Processing Record 244 of Set:6 | Motala
# City not found. Skipping...
# Processing Record 245 of Set:6 | Namatanai
# City not found. Skipping...
# Processing Record 246 of Set:6 | Alofi
# City not found. Skipping...
# Processing Record 247 of Set:6 | Atambua
# Processing Record 248 of Set:6 | Berlevag
# Processing Record 249 of Set:6 | Sandwick
# Processing Record 250 of Set:6 | Wamba
# Processing Record 251 of Set:6 | Ponta do Sol
# Processing Record 252 of Set:6 | Kieta
# Processing Record 253 of Set:6 | Jumla
# Processing Record 254 of Set:6 | Eyl
# Processing Record 255 of Set:6 | Esperance
# Processing Record 256 of Set:6 | Ibra
# Processing Record 257 of Set:6 | Zhangjiakou
# Processing Record 258 of Set:6 | Mackenzie
# Processing Record 259 of Set:6 | Grand Gaube
# Processing Record 260 of Set:6 | Asau
# Processing Record 261 of Set:6 | Phuket
# Processing Record 262 of Set:7 | Lima
# City not found. Skipping...
# Processing Record 263 of Set:7 | Luanda
# Processing Record 264 of Set:7 | Maragogi
# Processing Record 265 of Set:7 | Lander
# Processing Record 266 of Set:7 | Hami
# Processing Record 267 of Set:7 | Vegreville
# City not found. Skipping...
# Processing Record 268 of Set:7 | Kang
# Processing Record 269 of Set:7 | Bolgatanga
# Processing Record 270 of Set:7 | Zholymbet
# Processing Record 271 of Set:7 | Norsup
# Processing Record 272 of Set:7 | Ballina
# City not found. Skipping...
# Processing Record 273 of Set:7 | Miraflores
# Processing Record 274 of Set:7 | Mwinilunga
# Processing Record 275 of Set:7 | Gizo
# Processing Record 276 of Set:7 | Ferrol
# Processing Record 277 of Set:7 | Sitka
# Processing Record 278 of Set:7 | Nouadhibou
# Processing Record 279 of Set:7 | Bodaybo
# Processing Record 280 of Set:7 | Ucluelet
# Processing Record 281 of Set:7 | Shenjiamen
# Processing Record 282 of Set:7 | Eureka
# City not found. Skipping...
# Processing Record 283 of Set:7 | Khorol
# Processing Record 284 of Set:7 | San Quintin
# Processing Record 285 of Set:7 | Velikiy Novgorod
# City not found. Skipping...
# Processing Record 286 of Set:7 | Sao Pedro do Sul
# Processing Record 287 of Set:7 | Mongagua
# City not found. Skipping...
# Processing Record 288 of Set:7 | Rypin
# Processing Record 289 of Set:7 | Santa Cruz del Sur
# Processing Record 290 of Set:7 | Finschhafen
# Processing Record 291 of Set:7 | Hambantota
# Processing Record 292 of Set:7 | Carnarvon
# Processing Record 293 of Set:7 | Tessalit
# Processing Record 294 of Set:7 | Akhalgori
# Processing Record 295 of Set:7 | Taonan
# City not found. Skipping...
# Processing Record 296 of Set:7 | Salisbury
# Processing Record 297 of Set:7 | Tyukalinsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 298 of Set:7 | Lodja
# Processing Record 299 of Set:7 | Sistranda
# Processing Record 300 of Set:7 | Lavrentiya
# Processing Record 301 of Set:7 | Nambucca Heads
# Processing Record 302 of Set:7 | The Valley
# Processing Record 303 of Set:8 | Malinovoye Ozero
# Processing Record 304 of Set:8 | Iquitos
# Processing Record 305 of Set:8 | Fort Nelson
# Processing Record 306 of Set:8 | Glenwood Springs
# Processing Record 307 of Set:8 | Srednyaya Yelyuzan
# Processing Record 308 of Set:8 | Kaseda
# Processing Record 309 of Set:8 | Tubmanburg
# City not found. Skipping...
# Processing Record 310 of Set:8 | Punto Fijo
# Processing Record 311 of Set:8 | Viedma
# Processing Record 312 of Set:8 | Pasighat
# Processing Record 313 of Set:8 | Kande
# Processing Record 314 of Set:8 | Satara
# City not found. Skipping...
# Processing Record 315 of Set:8 | Jogindarnagar
# Processing Record 316 of Set:8 | Adrar
# Processing Record 317 of Set:8 | Qaqortoq
# City not found. Skipping...
# Processing Record 318 of Set:8 | Ilulissat
# Processing Record 319 of Set:8 | Norman Wells
# Processing Record 320 of Set:8 | Goderich
# Processing Record 321 of Set:8 | Mansfield
# Processing Record 322 of Set:8 | Torbay
# Processing Record 323 of Set:8 | Mineral Wells
# Processing Record 324 of Set:8 | Sumbe
# Processing Record 325 of Set:8 | Bhag
# City not found. Skipping...
# Processing Record 326 of Set:8 | Dawei
# Processing Record 327 of Set:8 | Debre Tabor
# City not found. Skipping...
# Processing Record 328 of Set:8 | Shubarshi
# Processing Record 329 of Set:8 | Visby
# Processing Record 330 of Set:8 | Zhangye
# City not found. Skipping...
# Processing Record 331 of Set:8 | La Palma
# Processing Record 332 of Set:8 | Faanui
# Processing Record 333 of Set:8 | Whitstable
# Processing Record 334 of Set:8 | Thompson
# Processing Record 335 of Set:8 | Impfondo
# City not found. Skipping...
# Processing Record 336 of Set:8 | Svetlyy
# Processing Record 337 of Set:8 | Evensk
# Processing Record 338 of Set:8 | Tilichiki
# Processing Record 339 of Set:8 | Cairns
# Processing Record 340 of Set:8 | West Bay
# Processing Record 341 of Set:8 | Waddan
# Processing Record 342 of Set:8 | Edson
# Processing Record 343 of Set:8 | Solaro
# Processing Record 344 of Set:8 | Constitucion
# Processing Record 345 of Set:8 | Samarai
# Processing Record 346 of Set:9 | Leningradskiy
# City not found. Skipping...
# Processing Record 347 of Set:9 | Yerbogachen
# Processing Record 348 of Set:9 | Los Llanos de Aridane
# Processing Record 349 of Set:9 | Port Blair
# Processing Record 350 of Set:9 | Dunedin
# Processing Record 351 of Set:9 | San Miguel
# Processing Record 352 of Set:9 | Maralal
# Processing Record 353 of Set:9 | Hovd
# Processing Record 354 of Set:9 | Kavieng
# Processing Record 355 of Set:9 | Svetlaya
# Processing Record 356 of Set:9 | Port Lincoln
# Processing Record 357 of Set:9 | Ust-Maya
# Processing Record 358 of Set:9 | Flinders
# Processing Record 359 of Set:9 | Zvishavane
# Processing Record 360 of Set:9 | Saint-Augustin
# Processing Record 361 of Set:9 | Batemans Bay
# Processing Record 362 of Set:9 | Yantal
# Processing Record 363 of Set:9 | New Glasgow
# City not found. Skipping...
# Processing Record 364 of Set:9 | Silver City
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 365 of Set:9 | Aykhal
# Processing Record 366 of Set:9 | San Jose
# Processing Record 367 of Set:9 | Cavalcante
# Processing Record 368 of Set:9 | Mount Isa
# Processing Record 369 of Set:9 | Chicama
# Processing Record 370 of Set:9 | Great Falls
# Processing Record 371 of Set:9 | Dudinka
# Processing Record 372 of Set:9 | Isla Vista
# Processing Record 373 of Set:9 | Hirado
# Processing Record 374 of Set:9 | Kruisfontein
# Processing Record 375 of Set:9 | Kyabram
# Processing Record 376 of Set:9 | Pasni
# City not found. Skipping...
# Processing Record 377 of Set:9 | Nuuk
# City not found. Skipping...
# Processing Record 378 of Set:9 | Port-Gentil
# Processing Record 379 of Set:9 | Umirim
# Processing Record 380 of Set:9 | Deputatskiy
# Processing Record 381 of Set:9 | Sayyan
# Processing Record 382 of Set:9 | Bonavista
# Processing Record 383 of Set:9 | Dingle
# Processing Record 384 of Set:9 | Floro
# Processing Record 385 of Set:9 | Yar-Sale
# Processing Record 386 of Set:9 | Belmonte
# Processing Record 387 of Set:9 | Cabo San Lucas
# Processing Record 388 of Set:9 | Berezovyy
# City not found. Skipping...
# Processing Record 389 of Set:10 | Ahuimanu
# City not found. Skipping...
# Processing Record 390 of Set:10 | Natal
# Processing Record 391 of Set:10 | Paracatu
# Processing Record 392 of Set:10 | Biltine
# Processing Record 393 of Set:10 | Sembe
# Processing Record 394 of Set:10 | Gornopravdinsk
# Processing Record 395 of Set:10 | Hamilton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 396 of Set:10 | Yinchuan
# Processing Record 397 of Set:10 | Sebinkarahisar
# Processing Record 398 of Set:10 | Kharp
# Processing Record 399 of Set:10 | Husavik
# City not found. Skipping...
# Processing Record 400 of Set:10 | Matay
# Processing Record 401 of Set:10 | Cabedelo
# Processing Record 402 of Set:10 | Fortuna
# Processing Record 403 of Set:10 | Laguna
# Processing Record 404 of Set:10 | Menongue
# Processing Record 405 of Set:10 | San Cristobal
# Processing Record 406 of Set:10 | Saint-Georges
# City not found. Skipping...
# Processing Record 407 of Set:10 | Babu
# Processing Record 408 of Set:10 | Yelizovo
# Processing Record 409 of Set:10 | La Rinconada
# Processing Record 410 of Set:10 | Erice
# Processing Record 411 of Set:10 | Chadan
# City not found. Skipping...
# Processing Record 412 of Set:10 | San Juan Bautista
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 413 of Set:10 | Beringovskiy
# Processing Record 414 of Set:10 | Vila Franca do Campo
# Processing Record 415 of Set:10 | Talnakh
# Processing Record 416 of Set:10 | Ulladulla
# Processing Record 417 of Set:10 | Bogatyye Saby
# Processing Record 418 of Set:10 | Chegdomyn
# Processing Record 419 of Set:10 | Rio Branco
# Processing Record 420 of Set:10 | Lorengau
# Processing Record 421 of Set:10 | Mabaruma
# Processing Record 422 of Set:10 | Gold Coast
# Processing Record 423 of Set:10 | Klaksvik
# Processing Record 424 of Set:10 | Gannan
# City not found. Skipping...
# Processing Record 425 of Set:10 | Ust-Tsilma
# Processing Record 426 of Set:10 | Callaway
# Processing Record 427 of Set:10 | Buala
# Processing Record 428 of Set:10 | Panama City
# Processing Record 429 of Set:10 | Kainantu
# Processing Record 430 of Set:11 | Perbaungan
# Processing Record 431 of Set:11 | Bako
# Processing Record 432 of Set:11 | Minot
# Processing Record 433 of Set:11 | Fuling
# City not found. Skipping...
# Processing Record 434 of Set:11 | Tuy Hoa
# Processing Record 435 of Set:11 | Roma
# Processing Record 436 of Set:11 | Oktyabrskoye
# Processing Record 437 of Set:11 | Louis Trichardt
# Processing Record 438 of Set:11 | Udachnyy
# City not found. Skipping...
# Processing Record 439 of Set:11 | Tabou
# Processing Record 440 of Set:11 | San Buenaventura
# Processing Record 441 of Set:11 | Sisimiut
# Processing Record 442 of Set:11 | Griffith
# Processing Record 443 of Set:11 | Kholm-Zhirkovskiy
# Processing Record 444 of Set:11 | Puri
# Processing Record 445 of Set:11 | Kortkeros
# Processing Record 446 of Set:11 | Meulaboh
# Processing Record 447 of Set:11 | Jacksonville Beach
# Processing Record 448 of Set:11 | Amarante
# Processing Record 449 of Set:11 | Strzelin
# Processing Record 450 of Set:11 | San Patricio
# Processing Record 451 of Set:11 | Ergani
# Processing Record 452 of Set:11 | Kelvington
# Processing Record 453 of Set:11 | Ayagoz
# Processing Record 454 of Set:11 | Fort Abbas
# City not found. Skipping...
# Processing Record 455 of Set:11 | Tarata
# Processing Record 456 of Set:11 | Beloha
# Processing Record 457 of Set:11 | Sola
# Processing Record 458 of Set:11 | Jiexiu
# Processing Record 459 of Set:11 | Taoudenni
# Processing Record 460 of Set:11 | Gamba
# Processing Record 461 of Set:11 | Mitu
# Processing Record 462 of Set:11 | Ribeira Brava
# Processing Record 463 of Set:11 | Port Keats
# Processing Record 464 of Set:11 | Tupiza
# Processing Record 465 of Set:11 | Qasigiannguit
# Processing Record 466 of Set:11 | Sulmona
# Processing Record 467 of Set:11 | Yuci
# Processing Record 468 of Set:11 | Kudahuvadhoo
# Processing Record 469 of Set:11 | Hofn
# Processing Record 470 of Set:11 | Peace River
# City not found. Skipping...
# Processing Record 471 of Set:11 | Bujumbura
# City not found. Skipping...
# Processing Record 472 of Set:11 | Anzio
# Processing Record 473 of Set:11 | Shingu
# Processing Record 474 of Set:11 | San Rafael del Sur
# Processing Record 475 of Set:12 | Santa Maria
# City not found. Skipping...
# Processing Record 476 of Set:12 | Torres
# Processing Record 477 of Set:12 | Macusani
# Processing Record 478 of Set:12 | Rawson
# Processing Record 479 of Set:12 | Chifeng
# Processing Record 480 of Set:12 | Roseburg
# Processing Record 481 of Set:12 | Roald
# Processing Record 482 of Set:12 | Bouloupari
# Processing Record 483 of Set:12 | Dekar
# Processing Record 484 of Set:12 | Amantea
# Processing Record 485 of Set:12 | Itoman
# Processing Record 486 of Set:12 | Minas
# City not found. Skipping...
# Processing Record 487 of Set:12 | Gidole
# Processing Record 488 of Set:12 | Hermitage
# Processing Record 489 of Set:12 | Herat
# Processing Record 490 of Set:12 | Shache
# Processing Record 491 of Set:12 | Keti Bandar
# Processing Record 492 of Set:12 | Ahipara
# Processing Record 493 of Set:12 | Hay River
# Processing Record 494 of Set:12 | Boende
# Processing Record 495 of Set:12 | Staryy Nadym
# Processing Record 496 of Set:12 | Tautira
# Processing Record 497 of Set:12 | Kutum
# Processing Record 498 of Set:12 | Zwedru
# Processing Record 499 of Set:12 | Tricase
# Processing Record 500 of Set:12 | Rossland
# Processing Record 501 of Set:12 | Chumikan
# Processing Record 502 of Set:12 | Tawang
# City not found. Skipping...
# Processing Record 503 of Set:12 | Vao
# Processing Record 504 of Set:12 | Kurilsk
# Processing Record 505 of Set:12 | Orotukan
# Processing Record 506 of Set:12 | Waipawa
# Processing Record 507 of Set:12 | Fallon
# Processing Record 508 of Set:12 | Casper
# City not found. Skipping...
# Processing Record 509 of Set:12 | Omboue
# Processing Record 510 of Set:12 | Prince George
# Processing Record 511 of Set:12 | Livingstonia
# Processing Record 512 of Set:12 | Alekseyevka
# Processing Record 513 of Set:12 | Christchurch
# Processing Record 514 of Set:12 | Kamenka
# Processing Record 515 of Set:12 | Caiaponia
# Processing Record 516 of Set:12 | Guane
# Processing Record 517 of Set:12 | Korla
# City not found. Skipping...
# Processing Record 518 of Set:12 | Itaituba
# Processing Record 519 of Set:12 | Saint-Leu
# Processing Record 520 of Set:13 | Mahajanga
# City not found. Skipping...
# Processing Record 521 of Set:13 | Yei
# Processing Record 522 of Set:13 | Kijang
# Processing Record 523 of Set:13 | Ketou
# Processing Record 524 of Set:13 | Port Hardy
# Processing Record 525 of Set:13 | Aguimes
# Processing Record 526 of Set:13 | Agadez
# City not found. Skipping...
# Processing Record 527 of Set:13 | Lac du Bonnet
# Processing Record 528 of Set:13 | Chambar
# City not found. Skipping...
# Processing Record 529 of Set:13 | Morondava
# Processing Record 530 of Set:13 | Mandera
# Processing Record 531 of Set:13 | Umm Kaddadah
# Processing Record 532 of Set:13 | Hemsedal
# Processing Record 533 of Set:13 | Balikpapan
# Processing Record 534 of Set:13 | Nichinan
# City not found. Skipping...
# Processing Record 535 of Set:13 | Mikkeli
# Processing Record 536 of Set:13 | Cockburn Town
# Processing Record 537 of Set:13 | Gari
# Processing Record 538 of Set:13 | Moberly
# Processing Record 539 of Set:13 | Port Macquarie
# City not found. Skipping...
# Processing Record 540 of Set:13 | Alyangula
# Processing Record 541 of Set:13 | Caronport
# Processing Record 542 of Set:13 | Buchanan
# Processing Record 543 of Set:13 | Lakes Entrance
# Processing Record 544 of Set:13 | Muzhi
# Processing Record 545 of Set:13 | Aleksandrov Gay
# Processing Record 546 of Set:13 | Isiro
# Processing Record 547 of Set:13 | Kugesi
# Processing Record 548 of Set:13 | Katol
# Processing Record 549 of Set:13 | Acajutla
# City not found. Skipping...
# Processing Record 550 of Set:13 | Muroto
# Processing Record 551 of Set:13 | Severnoye
# Processing Record 552 of Set:13 | Sovetskiy
# Processing Record 553 of Set:13 | Khash
# Processing Record 554 of Set:13 | Asansol
# Processing Record 555 of Set:13 | Touros
# Processing Record 556 of Set:13 | Taganak
# Processing Record 557 of Set:13 | Taltal
# Processing Record 558 of Set:13 | Ukiah
# City not found. Skipping...
# Processing Record 559 of Set:13 | Batagay-Alyta
# Processing Record 560 of Set:13 | Gladstone
# City not found. Skipping...
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# creating weather DataFrame
weather_df = pd.DataFrame({
    "City" : City,
    "Lat" : Lat,
    "Lng" : Lng,
    "Max Temp" : Max_Temp,
    "Humidity" : Humidity,
    "Cloudiness" : Cloudiness,
    "Wind Speed" : Wind_speed,
    "Country" : Country,
    "Date" : Date
})
weather_df.head()
weather_df.to_csv("weather.csv")

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean    21.396194   18.658830  288.709018   70.592857   57.169643    3.682036
# std     33.326572   90.720725   11.429151   21.399061   38.536299    2.661987
# min    -54.800000 -175.200000  248.320000    9.000000    0.000000    0.000000
# 25%     -7.197000  -57.636575  280.695000   57.000000   18.000000    1.717500
# 50%     27.889850   20.100700  290.135000   75.000000   68.500000    3.040000
# 75%     50.495300   95.532100  297.987500   87.000000   97.000000    5.232500
# max     78.218600  179.316700  313.140000  100.000000  100.000000   13.890000
#
#                Date
# count  5.600000e+02
# mean   1.634969e+09
# std    2.298530e+02
# min    1.634969e+09
# 25%    1.634969e+09
# 50%    1.634969e+09
# 75%    1.634969e+09
# max    1.634970e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#checking if any cities have >100% humidity
print(f'{sum(weather_df["Humidity"] > 100)} cities have a humidity > 100%')
df = weather_df.head(100)
# Out:
# 0 cities have a humidity > 100%

# %%
#  Get the indices of cities that have humidity over 100%.
hum_out = weather_df[weather_df["Humidity"] > 100].index

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df.drop(hum_out, inplace=False)
clean_city_data.describe()
sum(clean_city_data.duplicated())
# Out:
# 0

# %%
### FURTHER CLEANING DATA - DATE AND TEMPERATURE COLUMNS NEED TO BE CONVERTED
# created new col ("Simple_date") to convert Date from unix UTC to datetime
clean_city_data["Simple_Date"] = clean_city_data["Date"].apply(lambda d: datetime.fromtimestamp(int(d)).strftime('%Y-%m-%d'))
# substituded Max Temp from K to F using formula
clean_city_data["Max Temp"] = round((clean_city_data["Max Temp"] - 273.15) * 9/5 + 32 ,2)
# substitute Wind Speed from Default (meter/sec) to Imperial
clean_city_data["Wind Speed"] = round(clean_city_data["Wind Speed"]*2.237, 2)

# %%
# created new col ("Simple_date") to convert Date from unix UTC to datetime
clean_city_data["Simple_Date"] = clean_city_data["Date"].apply(lambda d: datetime.fromtimestamp(int(d)).strftime('%Y-%m-%d'))

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Max Temp"], edgecolor="black")
plt.grid()
plt.title(f'City Latitude vs. Maximum Temperature ({clean_city_data["Simple_Date"][0]})')
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig('output/Latitude_vs._Temperature_Plot.png')

# %%
### the above plot shows an inverse "U" relationship. Temperatures are lower as you get further away from the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Humidity"], edgecolor="black")
plt.grid()
plt.title(f'City Latitude vs. Humidity ({clean_city_data["Simple_Date"][0]})')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig('output/Latitude_vs_Humidity_Plot.png')
plt.show()

# %%
### the above plot shows that there does not appear to be a relationship between humidity and latitude

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Cloudiness"], edgecolor="black")
plt.grid()
plt.title(f'City Latitude vs. Cloudiness ({clean_city_data["Simple_Date"][0]})')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig('output/Latitude_vs_Cloudiness_Plot.png')
plt.show()

# %%
### the above plot shows that there does not appear to be a relationship between cloudiness and latitude

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_city_data["Lat"],clean_city_data["Wind Speed"], edgecolor="black")
plt.grid()
plt.title(f'City Latitude vs. Wind Speed ({clean_city_data["Simple_Date"][0]})')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig('output/Latitude_vs_Wind_Speed_Plot.png')
plt.show()

# %%
### the above plot shows that there does not appear to be a relationship between wind speed and latitude

# %% [markdown]
# ## Linear Regression

# %%
# Northern Hemisphere (greater than or equal to 0 degrees latitude)
north_hem = clean_city_data[clean_city_data["Lat"] >= 0]
# Southern Hemisphere (less than 0 degrees latitude)
south_hem = clean_city_data[clean_city_data["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hem["Lat"]
y_values = north_hem["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output/N_Hemisphere_Max_Temp_vs_Latitude_Linear_Regression.png')
plt.show()
# Out:
# The r-squared is: 0.7830827339367866

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hem["Lat"]
y_values = south_hem["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,90),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
print(f"The r-squared is: {rvalue**2}")
plt.savefig('output/S_Hemisphere_Max_Temp_vs_Latitude_Linear_Regression.png')
plt.show()
# Out:
# The r-squared is: 0.33173546543522925

# %%
### Northern Hemisphere: There appears to be a strong negative correlation between Max Temp and Latitude
###                      As latitude increases, Max Temperature decreases.

### Southern Hemisphere: There appears to be a weak positive correlation between Max Temp and Latitude
###                      As latitude increases, Max Temperature increases

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hem["Lat"]
y_values = north_hem["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(46,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.savefig('output/N_Hemisphere_Humidity_vs_Latitude_Linear_Regression.png')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.042841883294153074

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hem["Lat"]
y_values = south_hem["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.savefig('output/S_Hemisphere_Humidity_vs_Latitude_Linear_Regression.png')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.010042739296415264

# %%
### Northern and Southern Hemisphere: there seems to be a very weak positive correlation between Humidity and Latitude

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hem["Lat"]
y_values = north_hem["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(46,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.savefig('output/N_Hemisphere_Cloudiness_vs_Latitude_Linear_Regression.png')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.04611917568886115

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hem["Lat"]
y_values = south_hem["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,80),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.savefig('output/S_Hemisphere_Cloudiness_vs_Latitude_Linear_Regression.png')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0006353950876402967

# %%
### Northern and Southern Hemisphere:  there appears to be no correlation between Humidity and Latitude

# %% [markdown]
# ###  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hem["Lat"]
y_values = north_hem["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,35),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.savefig('output/N_Hemisphere_Wind_Speed_vs_Latitude_Linear_Regression.png')
plt.show()
# Out:
# The r-squared is: 0.029565787291950335

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hem["Lat"]
y_values = south_hem["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.savefig('output/S_Hemisphere_Wind_Speed_vs_Latitude_Linear_Regression.png')
plt.show()
# Out:
# The r-squared is: 0.18608252832423328

# %%
### Northern Hemisphere: there appears to be a very weak or no correlation between Wind Speed and Latitude
### Southern Hemisphere: there appears very weak negative correlation between Wind Speed and Latitude

# %%
# exporting data to csv file
clean_city_data.to_csv("output/WeatherPy.csv")
